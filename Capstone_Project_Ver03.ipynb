# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 2)
# Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# # Acknowledgment

# %% [markdown]
# <p>This project is based on a sample project that this course has introduced (<a href="https://cocl.us/coursera_capstone_notebook">Ref.</a>).</p>

# %% [markdown]
# # Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# # Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# Ho Chi Minh City (Saigon) is the business and financial hub of Vietnam. The population of HCM City in 2019 was put at 9.0 million people. The area is 2,095,239 km2 with 24 districts. The city develops and modernizes key sectors, namely trading, import-export, finance and banking, insurance, tourism, telecommunications, science and technology, and services for trading and production in HCM City and southern provinces. Today, Ho Chi Minh City is a popular tourist destination due to the fact that the weather is warm, fascinating culture, sleek skyscrapers, ornate temples, and pagodas. The city is also filled with bars, coffice shops, restaurants that overlook Saigon and beyond, while fantastic restaurants offer local Vietnamese cuisine. The city has contributed the largest budget in the country, dubbed the most livable city in Vietnam.
#
# In this project, we will try to find an **optimal location** for a **coffee shop**. Specifically, this report will be targeted to stakeholders interested in opening a coffee shop in the center of Ho Chi Minh City. This project will address the following 3 issues:
#
# Firstly, segmenting and Clustering Neighborhoods in Ho Chi Minh City. After segmenting and clustering, we locate the center. This location is located between Tan Son Nhat International Airport and the city center (District 1). This is the direction visitors will move when traveling to Vietnam and the ability to find a cafe. Next, using the Foursquare API to explore neighborhoods in the City.
#
# Secondly, finding reasonable areas to open a coffee shop. Because there are many coffee shops in Ho Chi Minh City, we will try to detect locations that are not already crowded with coffee shops. And, we are also particularly interested in areas with no cafe in the vicinity. We would also prefer locations as close to the city center as possible.
#
# Thirdly, after identifying a reasonable area, we analyze the data to find locations for opening the coffee shop in the most economical way.

# %% [markdown]
# # Data Description <a name="data"></a>

# %% [markdown]
# Based on the definition of the above problem, data factors that will influence this project as follows:
#
# - number of existing coffee shops in the area
# - number of and distance of coffee shops each other in the area
# - a distance of the area from the central location (This location is located between Tan Son Nhat International Airport and the city center).
#
# We will create a grid of cells covering our area of interest which is approx. The radius of 12 kilometers centered around the center location that we defined.
#
# We use a regularly spaced grid of locations, centered around the central location, to define areas.
#
# Following data sources will be needed to extract/generate the required information:
#
# - centers of candidate areas will be generated algorithmically and approximate addresses of centers of those areas will be obtained.
#
# - using Google Maps API reverse geocoding number of the coffee shops and their type and location in every area will be obtained using Foursquare API.
#
# - coordinate of the central location will be obtained using Google Maps API geocoding.

# %% [markdown]
# # Area Candidates
#
# Let's create latitude & longitude coordinates for centroids of candidate areas. We will create a grid of cells covering our area of interest which is aprox. 12x12 killometers centered around central location.
#
# Let's first find the latitude & longitude of the central location, using specific, well known address and Google Maps geocoding API.

# %%
import requests

def get_coordinates(api_key, address, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&address={}'.format(api_key, address)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        geographical_data = results[0]['geometry']['location'] # get geographical coordinates
        lat = geographical_data['lat']
        lon = geographical_data['lng']
        return [lat, lon]
    except:
        return [None, None]
    
address = 'Ủy ban nhân dân Tp.HCM, Lê Thánh Tôn, Phường Bến Nghé, Quận 1, Hồ Chí Minh, Việt Nam'
address2 = 'Sân bay quốc tế Tân Sơn Nhất, Trường Sơn, Phường 2, Quận Tân Bình, Hồ Chí Minh, Việt Nam'
google_api_key = 'AIzaSyAQWqMTOcyLBRDR2skO4F_5QEWzNDOlUHw'

hcmc_center1 = get_coordinates(google_api_key, address)
hcmc_center2 = get_coordinates(google_api_key, address2)

hcmc_center = []
hcmc_center.append((hcmc_center1[0] + hcmc_center2[0])/2)
hcmc_center.append((hcmc_center1[1] + hcmc_center2[1])/2)

print('Coordinate of {}: {}'.format('The central location of Ho Chi Minh City', hcmc_center))
# Out:
# Coordinate of The central location of Ho Chi Minh City: [10.79751205, 106.67989825]

# %%
# !pip install shapely
# !pip install pyproj
# Out:
# Requirement already satisfied: shapely in c:\python37_64\lib\site-packages (1.6.4.post2)
# Requirement already satisfied: pyproj in c:\python37_64\lib\site-packages (2.2.2)

# %%
import shapely.geometry
import pyproj
import math

def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

def xy_to_lonlat(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lonlat[0], lonlat[1]

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)

print('Coordinate transformation check')
print('-------------------------------')

print('Cenrral location longitude = {}, latitude = {}'.format(hcmc_center[1], hcmc_center[0]))
x, y = lonlat_to_xy(hcmc_center[1], hcmc_center[0])

print('Cenrral location UTM X = {}, Y = {}'.format(x, y))
lo, la = xy_to_lonlat(x, y)

print('Cenrral location longitude = {}, latitude = {}'.format(lo, la))
# Out:
# Coordinate transformation check
# -------------------------------
# Cenrral location longitude = 106.67989825, latitude = 10.79751205
# Cenrral location UTM X = 15220787.389165862, Y = 10899793.552625168
# Cenrral location longitude = 106.67993419927984, latitude = 10.797525700662865

# %% [markdown]
# Let's create a **hexagonal grid of cells**: we offset every other row, and adjust vertical row spacing so that **every cell center is equally distant from all it's areas**.

# %%
hcmc_center_x, hcmc_center_y = lonlat_to_xy(
    hcmc_center[1], hcmc_center[0])  # City center in Cartesian coordinates

(hcmc_center_x, hcmc_center_y)
# Out:
# (15220787.389165862, 10899793.552625168)

# %%
k = math.sqrt(3) / 2 # Vertical offset for hexagonal grid cells
x_min = hcmc_center_x - 12000 #6000
x_step = 600
y_min = hcmc_center_y - 12000 #- (int(21/k)*k*600 - 12000)/2
y_step = 600 * k

(k, x_min, x_step, y_min, y_step)
# Out:
# (0.8660254037844386,
#  15208787.389165862,
#  600,
#  10887793.552625168,
#  519.6152422706632)

# %%
latitudes = []
longitudes = []
distances_from_center = []
xs = []
ys = []


for i in range(0, int(41/k)):
    y = y_min + i * y_step
    x_offset = 300 #if i%2==0 else 0
    
    for j in range(0, 41):
        x = x_min + j * x_step + x_offset
        distance_from_center = calc_xy_distance(hcmc_center_x, hcmc_center_y, x, y)
        if (distance_from_center <= 12001):
            lon, lat = xy_to_lonlat(x, y)
            latitudes.append(lat)
            longitudes.append(lon)
            distances_from_center.append(distance_from_center)
            xs.append(x)
            ys.append(y)

print(len(latitudes), 'candidate area centers generated.')
# Out:
# 1452 candidate area centers generated.

# %% [markdown]
# Let's visualize the data we have so far: city center location and candidate areas centers:

# %%
#!pip install folium

import folium

# %%
map_hcmc = folium.Map(location = hcmc_center, zoom_start=13)
folium.Marker(hcmc_center, popup='Central location').add_to(map_hcmc)


for lat, lon in zip(latitudes, longitudes):
    #folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_hcmc) 
    folium.Circle([lat, lon], radius=60, color='red', fill=False).add_to(map_hcmc)
    #folium.Marker([lat, lon]).add_to(map_hcmc)
map_hcmc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# OK, we now have the coordinates of centers of neighborhoods/areas to be evaluated, equally spaced (distance from every point to it's neighbors is exactly the same) and within ~6km from central location.
#
# Let's now use Google Maps API to get approximate addresses of those locations.

# %%
def get_address(api_key, latitude, longitude, verbose=False):
    try:
        url = 'https://maps.googleapis.com/maps/api/geocode/json?key={}&latlng={},{}'.format(api_key, latitude, longitude)
        response = requests.get(url).json()
        if verbose:
            print('Google Maps API JSON result =>', response)
        results = response['results']
        address = results[0]['formatted_address']
        return address
    except:
        return None

addr = get_address(google_api_key, hcmc_center[0], hcmc_center[1])
print('Reverse geocoding check')
print('-----------------------')
print('Address of [{}, {}] is: {}'.format(hcmc_center[0], hcmc_center[1], addr))
# Out:
# Reverse geocoding check
# -----------------------
# Address of [10.79751205, 106.67989825] is: 3 Trần Khắc Trân, Phường 15, Phú Nhuận, Hồ Chí Minh, Vietnam

# %%
print('Obtaining location addresses: ', end='')
addresses = []
for lat, lon in zip(latitudes, longitudes):
    address = get_address(google_api_key, lat, lon)
    if address is None:
        address = 'NO ADDRESS'
    address = address.replace(', Vietnam', '') # We don't need country part of address
    addresses.append(address)
    print(' .', end='')
print(' done.')
# Out:
# Obtaining location addresses:  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . done.

# %%
len(addresses)
# Out:
# 1452

# %%
addresses
# Out:
# ['30 Phan Thúc Duyện, Phường 4, Tân Bình, Hồ Chí Minh',
#  '6/22 Hẻm số 6 Đồ Sơn, Phường 4, Tân Bình, Hồ Chí Minh',
#  '27 Sầm Sơn, Phường 4, Tân Bình, Hồ Chí Minh',
#  '36/14 Hẻm 36 Giải Phóng, Phường 4, Tân Bình, Hồ Chí Minh',
#  '2/15 Hẻm số 2 Đồng Khởi, Phường 4, Tân Bình, Hồ Chí Minh',
#  '15 Cộng Hòa, Phường 4, Tân Bình, Hồ Chí Minh',
#  '51 Nguyễn Thái Bình, Phường 4, Tân Bình, Hồ Chí Minh',
#  '308/5 Hoàng Văn Thụ, Phường 4, Tân Bình, Hồ Chí Minh',
#  '40a, 40B Út Tịch, Phường 4, Tân Bình, Hồ Chí Minh',
#  '437/13- 437/15 Hoàng Văn Thụ, Phường 4, Tân Bình, Hồ Chí Minh',
#  '27 Nguyễn Đình Khơi, Phường 4, Tân Bình, Hồ Chí Minh',
#  '61 Nguyễn Đình Khơi, Phường 4, Tân Bình, Hồ Chí Minh',
#  '130 Thăng Long, Phường 4, Tân Bình, Hồ Chí Minh',
#  'Nhà ga hàng hóa quốc tế Sân bay Tân Sơn Nhất, Nguyễn Văn Vĩnh, Phường 4, Tân Bình, Hồ Chí Minh',
#  '6bis Thăng Long, Phường 4, Tân Bình, Hồ Chí Minh',
#  '28, Đường Phan Thúc Duyện, Phường 4, Tân Bình, Hồ Chí Minh',
#  '3 Hẻm số 3 Đồ Sơn, Phường 4, Tân Bình, Hồ Chí Minh',
#  '47/17 Hẻm 47 Thăng Long, Phường 4, Tân Bình, Hồ Chí Minh',
#  '25/13 Hẻm số 25 Thăng Long, Phường 4, Tân Bình, Hồ Chí Minh',
#  '55 Cộng Hòa, Phường 4, Tân Bình, Hồ Chí Minh',
#  '238/7 Hoàng Văn Thụ, Phường 4, Tân Bình, Hồ Chí Minh',
#  '429/8 Hoàng Văn Thụ, Phường 2, Tân Bình, Hồ Chí Minh',
#  '27A Hoàng Việt, Phường 4, Quận Tân Bình, Phường 4, Tân Bình, Hồ Chí Minh',
#  '16/2 Hoàng Việt, Phường 4, Tân Bình, Hồ Chí Minh',
#  '26 Hoàng Việt, Phường 4, Tân Bình, Hồ Chí Minh',
#  '39 Hoàng Việt, Phường 4, Tân Bình, Hồ Chí Minh',
#  '892B Cách Mạng Tháng 8, Phường 4, Tân Bình, Hồ Chí Minh',
#  '368/710 Hẻm 204 Cách Mạng Tháng Tám, Phường 4, Tân Bình, Hồ Chí Minh',
#  '6 Thăng Long, Phường 4, Tân Bình, Hồ Chí Minh',
#  '49 Trường Sơn, Phường 2, Tân Bình, Hồ Chí Minh',
#  '51A Hậu Giang, Phường 4, Tân Bình, Hồ Chí Minh',
#  '98 Thăng Long, Phường 4, Tân Bình, Hồ Chí Minh',
#  '58a Thăng Long, Phường 4, Tân Bình, Hồ Chí Minh',
#  '36 Thăng Long, Phường 4, Tân Bình, Hồ Chí Minh',
#  '83 Thăng Long, Phường 4, Tân Bình, Hồ Chí Minh',
#  '45 Thăng Long, Phường 4, Tân Bình, Hồ Chí Minh',
#  '20 Thăng Long, Phường 4, Tân Bình, Hồ Chí Minh',
#  '1B1 Cộng Hòa, Phường 4, Tân Bình, Hồ Chí Minh',
#  '381/4 Hoàng Văn Thụ, Phường 2, Tân Bình, Hồ Chí Minh',
#  '274c Nguyễn Trọng Tuyển, Hồ Chí Minh',
#  '1/35 Hoàng Việt, Phường 4, Tân Bình, Hồ Chí Minh',
#  '21 Hoàng Việt, Phường 4, Tân Bình, Hồ Chí Minh',
#  '25/5, Hoàng Việt, P.4, Q.Tân Bình, 25/5 Hẻm 25 Hoàng Việt, Tân Bình, Hồ Chí Minh',
#  '654 Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  '368 Hoàng Sa, Phường 5, Tân Bình, Hồ Chí Minh',
#  'Ke 344/582 Cách Mạng Tháng 8, Phường 5, Tân Bình, Hồ Chí Minh',
#  '320/531 Hẻm 204 Cách Mạng Tháng Tám, Phường 5, Tân Bình, Hồ Chí Minh',
#  '1008 Hẻm 204 Cách Mạng Tháng Tám, Phường 7, Tân Bình, Hồ Chí Minh',
#  'Unnamed Road, Phường 2, Tân Bình, Hồ Chí Minh',
#  '49 Trường Sơn, Phường 2, Tân Bình, Hồ Chí Minh',
#  '40 Hậu Giang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '46-48 Hậu Giang, Phường 4, Tân Bình, Hồ Chí Minh',
#  '3 Nguyễn Văn Vĩnh, Phường 4, Tân Bình, Hồ Chí Minh',
#  '77 Nguyễn Trọng Lội, Phường 4, Tân Bình, Hồ Chí Minh',
#  '10 Nguyễn Cảnh Dị, Phường 4, Tân Bình, Hồ Chí Minh',
#  '6 Phan Thúc Duyện, Phường 4, Tân Bình, Hồ Chí Minh',
#  '22 Trần Quốc Hoàn, Phường 4, Tân Bình, Hồ Chí Minh',
#  '2/35 Thăng Long, Phường 4, Tân Bình, Hồ Chí Minh',
#  '315 Hoàng Văn Thụ, Phường 2, Tân Bình, Hồ Chí Minh',
#  '430 Đường Lê Văn Sỹ, Phường 2, Tân Bình, Hồ Chí Minh',
#  '21 Nguyễn Thanh Tuyền, Phường 2, Tân Bình, Hồ Chí Minh',
#  '76 Nguyễn Thanh Tuyền, Phường 2, Tân Bình, Hồ Chí Minh',
#  '504/14/80 Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  '501/5 Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  '421/28D Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  '262/11 Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  '318/64 Phạm Văn Hai, Phường 5, Tân Bình, Hồ Chí Minh',
#  '380/310 Phạm Văn Hai, Phường 5, Tân Bình, Hồ Chí Minh',
#  '222 Hẻm 204 Cách Mạng Tháng Tám, Phường 5, Tân Bình, Hồ Chí Minh',
#  '149/39, Bành Văn Trân, Phường 7, Quận Tân Bình, Thành Phố Hồ Chí Minh, Phường 7, Tân Bình, Hồ Chí Minh',
#  'Airport Dr, Phường 2, Tân Bình, Hồ Chí Minh',
#  '55/17 Trường Sơn, Phường 2, Tân Bình, Hồ Chí Minh',
#  '{{Province, Phường 2, Tân Bình, Hồ Chí Minh',
#  '39 Trường Sơn, Phường 2, Tân Bình, Hồ Chí Minh',
#  '2 Hậu Giang, Phường 4, Tân Bình, Hồ Chí Minh',
#  '21/22 Hẻm 21 Trường Sơn, Phường 4, Tân Bình, Hồ Chí Minh',
#  '1/11A Trường Sơn, Phường 4, Tân Bình, Hồ Chí Minh',
#  '33-34 Hẻm số 2 Phan Thúc, Phường 4, Tân Bình, Hồ Chí Minh',
#  '30, Phan Thúc Duyện, Phường 4, Quận Tân Bình, Phường 4, Tân Bình, Hồ Chí Minh',
#  '22 Trần Quốc Hoàn, Phường 4, Tân Bình, Hồ Chí Minh',
#  '20 Trần Quốc Hoàn, Phường 2, Tân Bình, Hồ Chí Minh',
#  '271/1 Hoàng Văn Thụ, Phường 2, Tân Bình, Hồ Chí Minh',
#  '25 Bùi Thị Xuân, Phường 2, Tân Bình, Hồ Chí Minh',
#  '138 Ngô Thị Thu Minh, Phường 2, Tân Bình, Hồ Chí Minh',
#  '87 Tân Sơn Hoà, Phường 3, Tân Bình, Hồ Chí Minh',
#  '130/17D Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  '403B Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  '330/17 Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  '148/24/14 Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  'Cầu Số 2, phường 5, Tân Bình, Hồ Chí Minh',
#  '278 Phạm Văn Hai, Phường 5, Tân Bình, Hồ Chí Minh',
#  '273 Phạm Văn Hai, Phường 5, Tân Bình, Hồ Chí Minh',
#  '6 Bành Văn Trân, Phường 6, Tân Bình, Hồ Chí Minh',
#  '8/22 Hẻm Phú Lộc KP7, Phường 6, Tân Bình, Hồ Chí Minh',
#  '2 Hồng Hà, Phường 2, Tân Bình, Hồ Chí Minh',
#  '60c Trường Sơn, Phường 2, Tân Bình, Hồ Chí Minh',
#  '152 Bus Station, Phường 2, Tân Bình, Hồ Chí Minh',
#  '52 Trường Sơn, Phường 2, Tân Bình, Hồ Chí Minh',
#  '32 Trường Sơn, Phường 2, Tân Bình, Hồ Chí Minh',
#  '18 Trường Sơn, Phường 2, Tân Bình, Hồ Chí Minh',
#  '2a-2b Trường Sơn, Phường 4, Tân Bình, Hồ Chí Minh',
#  '61 Trường Sơn, Phường 4, Tân Bình, Hồ Chí Minh',
#  '18, Trần Quốc Hoàn, Phường 4, Quận Tân Bình, Thành Phố Hồ Chí Minh, Phường 2, Tân Bình, Hồ Chí Minh',
#  '63 Tran Quoc Hoan, Ward 4, District Tan Binh, HCMC, Trần Quốc Hoàn, Tân Bình, Hồ Chí Minh',
#  '44 Phan Thúc Duyện, Phường 2, Tân Bình, Hồ Chí Minh',
#  'Công viên Hoàng Văn Thụ, Phường 2, Tân Bình, Hồ Chí Minh',
#  'Công viên Hoàng Văn Thụ, Phường 2, Tân Bình, Hồ Chí Minh',
#  '342/1 Nguyễn Trọng Tuyển, Phường 2, Tân Bình, Hồ Chí Minh',
#  '447 Đường Lê Văn Sỹ, Phường 2, Tân Bình, Hồ Chí Minh',
#  '86/1 Bùi Thị Xuân, Phường 3, Tân Bình, Hồ Chí Minh',
#  '130/C4A Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  'Sạp C/65-66, Chợ Phạm Văn Hai, Quận Tân Bình, Phường 3, Tân Bình, Hồ Chí Minh',
#  '128/39 Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  '109C Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  '1279 Hoàng Sa, Phường 5, Tân Bình, Hồ Chí Minh',
#  '187/14 Phạm Văn Hai, Phường 5, Tân Bình, Hồ Chí Minh',
#  '235/60 Phạm Văn Hai, Phường 5, Tân Bình, Hồ Chí Minh',
#  '783/17 Cách Mạng Tháng 8, Phường 6, Tân Bình, Hồ Chí Minh',
#  '165/1 Đ.Phạm Văn Hai 0, Phường 6, Tân Bình, Hồ Chí Minh',
#  'D.Chan hưngP6, Phường 6, Tân Bình, Hồ Chí Minh',
#  '2B/32 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '2 Hồng Hà, Phường 2, Tân Bình, Hồ Chí Minh',
#  '25/35/14 Cửu Long, Phường 2, Tân Bình, Hồ Chí Minh',
#  '25/13/10 Cửu Long, Phường 2, Tân Bình, Hồ Chí Minh',
#  '23 Hẻm 50 Trường Sơn, Phường 2, Tân Bình, Hồ Chí Minh',
#  'Công ty logistics Atlas, 5 Đống Đa, Phường 2, Tân Bình, Hồ Chí Minh',
#  '6A Đồng Nai, Phường 2, Tân Bình, Hồ Chí Minh',
#  '13 Sông Đáy, Phường 2, Tân Bình, Hồ Chí Minh',
#  '24 Trà Khúc, Phường 2, Tân Bình, Hồ Chí Minh',
#  '3E/11 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '4 Phan Đình Giót, Phường 2, Tân Bình, Hồ Chí Minh',
#  '26 Phan Thúc Duyện, Phường 2, Tân Bình, Hồ Chí Minh',
#  '19 Phan Thúc Duyện, Phường 2, Tân Bình, Hồ Chí Minh',
#  '253 Hoàng Văn Thụ, Phường 2, Tân Bình, Hồ Chí Minh',
#  '6/13 Phạm Văn Hai, Phường 2, Tân Bình, Hồ Chí Minh',
#  '12/15 Phạm Văn Hai, Phường 2, Tân Bình, Hồ Chí Minh',
#  '44/30 Phạm Văn Hai, Phường 2, Tân Bình, Hồ Chí Minh',
#  '59 Phạm Văn Hai, Phường 1, Tân Bình, Hồ Chí Minh',
#  '40/2 Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  '37/3 Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  '5/24 Phạm Văn Hai, Phường 3, Tân Bình, Hồ Chí Minh',
#  '165/37/14 Phạm Văn Hai, Phường 5, Tân Bình, Hồ Chí Minh',
#  '98/121 Thăng Long, Phường 5, Tân Bình, Hồ Chí Minh',
#  '51/5 Cách Mạng Tháng 8, Phường 5, Tân Bình, Hồ Chí Minh',
#  '736/18 Cách Mạng Tháng 8, Phường 5, Tân Bình, Hồ Chí Minh',
#  '28/1 Chấn hưng P6, Phường 6, Tân Bình, Hồ Chí Minh',
#  '46/1 Chấn hưng P6, Phường 6, Tân Bình, Hồ Chí Minh',
#  '176 Bắc Hải P6, Phường 6, Tân Bình, Hồ Chí Minh',
#  'Room no.602, 6th Floor, Bluesky Tower, No. 1 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  'B8A Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '50 Lam Sơn, Phường 2, Tân Bình, Hồ Chí Minh',
#  '40/2 Lam Sơn, Phường 2, Tân Bình, Hồ Chí Minh',
#  '43 Lam Sơn, Phường 2, Tân Bình, Hồ Chí Minh',
#  '16B/4, Cửu Long, Phường 2, Quận Tân Bình, Thành Phố Hồ Chí Minh, Phường 2, Tân Bình, Hồ Chí Minh',
#  '45 Tiền Giang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '21B Lam Sơn, Phường 2, Tân Bình, Hồ Chí Minh',
#  '21 Sông Nhuệ, Phường 2, Tân Bình, Hồ Chí Minh',
#  '10 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '3e/16 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '1A Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '1 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '28 Phan Thúc Duyện, Phường 2, Tân Bình, Hồ Chí Minh',
#  '1duong Phạm Văn Hai, Phường 1, Tân Bình, Hồ Chí Minh',
#  '3h Phạm Văn Hai, Phường 1, Tân Bình, Hồ Chí Minh',
#  '9/7 Phạm Văn Hai, Phường 1, Tân Bình, Hồ Chí Minh',
#  '305/62, Lê Văn Sỹ, Phường 1, Quận Tân Bình, Thành Phố Hồ Chí Minh, Phường 1, Tân Bình, Hồ Chí Minh',
#  '337/2/8 Đường Lê Văn Sỹ, Phường 1, Tân Bình, Hồ Chí Minh',
#  '193/2D Bùi Thị Xuân, Phường 1, Tân Bình, Hồ Chí Minh',
#  '178 Bùi Thị Xuân, Phường 3, Tân Bình, Hồ Chí Minh',
#  '16/12 Bùi Thị Xuân, Phường 3, Tân Bình, Hồ Chí Minh',
#  '13 Phạm Văn Hai, Phường 5, Tân Bình, Hồ Chí Minh',
#  '98/94/63 Thăng Long, Phường 5, Tân Bình, Hồ Chí Minh',
#  '15/2 Cách Mạng Tháng 8, Phường 5, Tân Bình, Hồ Chí Minh',
#  '11/4 Cách Mạng Tháng 8, Phường 5, Tân Bình, Hồ Chí Minh',
#  '4 tổ 84 Chấn HưngP6, Phường 6, Tân Bình, Hồ Chí Minh',
#  '84 Bắc Hải, Phường 15, Tân Bình, Hồ Chí Minh',
#  '84 Bắc Hải, Phường 15, Quận 10, Hồ Chí Minh',
#  '8 Nguyễn Giản Thanh, Cư xá Bắc Hải, Quận 10, Hồ Chí Minh',
#  '2A/58 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  'B42 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '13, 6 Yên Thế, Phường 2, Tân Bình, Hồ Chí Minh',
#  '58A Hồng Hà, Phường 2, Tân Bình, Hồ Chí Minh',
#  '15/2 Yên Thế, Phường 2, Tân Bình, Hồ Chí Minh',
#  '55-57 Cửu Long, Phường 2, Tân Bình, Hồ Chí Minh',
#  '3/9 Yên Thế, Phường 2, Tân Bình, Hồ Chí Minh',
#  '17A Sông Thương, Phường 2, Tân Bình, Hồ Chí Minh',
#  '72, Đường Thích Minh Nguyệt, Phường 2, Tân Bình, Hồ Chí Minh',
#  '4/1/K30 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  'Phòng 806, Khu B, Tòa Nhà Waseco, 10, Đường Phổ Quang, Quận Tân Bình, Phường 2, Tân Bình, Hồ Chí Minh',
#  '54/15 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '14A/7 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '2C Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '62 Phan Đình Giót, Phường 2, Tân Bình, Hồ Chí Minh',
#  '245E/11 Hoàng Văn Thụ, Phường 1, Tân Bình, Hồ Chí Minh',
#  '326A Nguyễn Trọng Tuyển, Phường 1, Tân Bình, Hồ Chí Minh',
#  '357A/15 Nguyễn Trọng Tuyển, Phường 1, Tân Bình, Hồ Chí Minh',
#  '261, Lê Văn Sỹ, Phường 1, Quận Tân Bình, Thành Phố Hồ Chí Minh, Phường 1, Tân Bình, Hồ Chí Minh',
#  '337/63 Đường Lê Văn Sỹ, Phường 1, Tân Bình, Hồ Chí Minh',
#  '333/12/11 Đường Lê Văn Sỹ, Phường 1, Tân Bình, Hồ Chí Minh',
#  '229/19 Bùi Thị Xuân, Phường 1, Tân Bình, Hồ Chí Minh',
#  '218 Bùi Thị Xuân, Phường 3, Tân Bình, Hồ Chí Minh',
#  '23/29 Bùi Thị Xuân, Phường 3, Tân Bình, Hồ Chí Minh',
#  '436D/64 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '6/14 Cách Mạng Tháng 8, Phường 5, Tân Bình, Hồ Chí Minh',
#  '436C/34 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '1 Bắc Hải, Phường 15, Quận 10, Hồ Chí Minh',
#  '48, Đường Bắc Hải, Phường 6, Quận Tân Bình, Phường 15, Quận 10, Hồ Chí Minh',
#  '875 Cách Mạng Tháng 8, Phường 15, Quận 10, Hồ Chí Minh',
#  '25 Trường Sơn, Phường 15, Quận 10, Hồ Chí Minh',
#  'BB14BIS Trường Sơn, Phường 15, Quận 10, Hồ Chí Minh',
#  '2 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '20/3 Yên Thế, Phường 2, Tân Bình, Hồ Chí Minh',
#  '124/1 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '76 Hồng Hà, Phường 2, Tân Bình, Hồ Chí Minh',
#  '6/5 Yên Thế, Phường 2, Tân Bình, Hồ Chí Minh',
#  '20/22B Yên Thế, Phường 2, Tân Bình, Hồ Chí Minh',
#  '2/3 Yên Thế, Phường 2, Tân Bình, Hồ Chí Minh',
#  '101duong Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  'Cây xăng Quân đội, Phường 2, Tân Bình, Hồ Chí Minh',
#  '86 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  'To 59 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '64/30/6 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '14/36 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '2 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  'Kiosque D10, D12, D13 sân vận động Quân khu 7, vào cổng đường Phan Đình Giót, rẽ phải 50m, Hoàng Văn Thụ, Phường 2, Tân Bình, Hồ Chí Minh',
#  '243B Hoàng Văn Thụ, Phường 1, Tân Bình, Hồ Chí Minh',
#  '309/10 Nguyễn Văn Trỗi, Phường 1, Tân Bình, Hồ Chí Minh',
#  '353/8 Nguyễn Trọng Tuyển, Phường 1, Tân Bình, Hồ Chí Minh',
#  '236B Đường Lê Văn Sỹ, Phường 1, Tân Bình, Hồ Chí Minh',
#  '315 Đường Lê Văn Sỹ, Phường 1, Tân Bình, Hồ Chí Minh',
#  '305 Đường Lê Văn Sỹ, Phường 1, Tân Bình, Hồ Chí Minh',
#  '281/54/10 Đường Lê Văn Sỹ, Phường 1, Tân Bình, Hồ Chí Minh',
#  '281/41/3 Đường Lê Văn Sỹ, Phường 1, Tân Bình, Hồ Chí Minh',
#  '1254 Trường Sa, Phường 14, Phú Nhuận, Hồ Chí Minh',
#  '64/11 Bùi Thị Xuân, Phường 11, Tân Bình, Hồ Chí Minh',
#  '656/45 Hẻm 656 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '648/28 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '462L/8 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '489 Cách Mạng Tháng 8, Phường 15, Quận 10, Đồng Nai',
#  'Công Viên Lê Thị Riêng, Cư xá Bắc Hải, Phường 15, Quận 10, Hồ Chí Minh',
#  '2 Trường Sơn, Phường 15, Quận 10, Hồ Chí Minh',
#  '82bis Nguyễn Giản Thanh, Phường 15, Quận 10, Hồ Chí Minh',
#  'A75/6 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  'A75/6A Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '5F Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh 736464',
#  '6 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '117 Hồng Hà, Phường 2, Tân Bình, Hồ Chí Minh',
#  '117 Hồng Hà, Phường 2, Tân Bình, Hồ Chí Minh',
#  '43 Hồng Hà, Phường 2, Tân Bình, Hồ Chí Minh',
#  '59 Hồng Hà, Phường 2, Tân Bình, Hồ Chí Minh',
#  '102 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '86 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '66/58 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  'Chua Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '24/8 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  'Hẻm 202/5 Hoàng Văn Thụ, Phường 2, Tân Bình, Hồ Chí Minh',
#  '240 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '202 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '307/10 Nguyễn Văn Trỗi, Phường 1, Tân Bình, Hồ Chí Minh',
#  '306A Nguyễn Văn Trỗi, Phường 1, Tân Bình, Hồ Chí Minh',
#  '343/19G Nguyễn Trọng Tuyển, Phường 1, Tân Bình, Hồ Chí Minh',
#  '343/83 Nguyễn Trọng Tuyển, Phường 1, Tân Bình, Hồ Chí Minh',
#  '226/8 Đường Lê Văn Sỹ, Phường 1, Tân Bình, Hồ Chí Minh',
#  '281/12 Đường Lê Văn Sỹ, Phường 1, Tân Bình, Hồ Chí Minh',
#  '281/23/14 Đường Lê Văn Sỹ, Phường 1, Tân Bình, Hồ Chí Minh',
#  '415/16, Truong Chinh Street, Ward 14, Tan Binh District, Phường 14, Phú Nhuận, Hồ Chí Minh',
#  '173Q Đặng Văn Ngữ, Phường 14, Phú Nhuận, Hồ Chí Minh',
#  '1220 Trường Sa, Phường 14, Phú Nhuận, Hồ Chí Minh',
#  '464/120/C3 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '590 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '462KT14 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '629/31 Trường Sơn, Phường 15, Quận 10, Hồ Chí Minh',
#  '629/68C Cách Mạng Tháng 8, Phường 15, Quận 10, Hồ Chí Minh',
#  '132/1B/C27 Tô Hiến Thành, Phường 15, Quận 10, Hồ Chí Minh',
#  '134/1/8C Tô Hiến Thành, Phường 15, Quận 10, Hồ Chí Minh',
#  '87 Tam Đảo, Cư xá Bắc Hải, Quận 10, Hồ Chí Minh',
#  'A75, Tân Bình',
#  'A75/42 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  'A75/6D/10 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '1/45 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh 736464',
#  '54/1/14 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '54/3/26 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '117 Hồng Hà, Phường 2, Tân Bình, Hồ Chí Minh',
#  '89 Hồng Hà, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '117 Phổ Quang, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '102, Phổ Quang, Phường 2, Quận Tân Bình, Thành Phố Hồ Chí Minh, Phường 2, Tân Bình, Hồ Chí Minh',
#  '86/36/3 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '119 Phổ Quang, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '64/5 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  '64/5 Phổ Quang, Phường 2, Tân Bình, Hồ Chí Minh',
#  'Unnamed Road, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  'Unnamed Road, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '202 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '178 Nguyễn Văn Trỗi, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '250/1 Nguyễn Trọng Tuyển, Phường 1, Tân Bình, Hồ Chí Minh',
#  '10/9A Đặng Văn Ngữ, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '16/2/3 Đặng Văn Ngữ, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '32/14 Đặng Văn Ngữ, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '206 Đường Lê Văn Sỹ, Phường 14, Phú Nhuận, Hồ Chí Minh',
#  '77 Đặng Văn Ngữ, Phường 14, Phú Nhuận, Hồ Chí Minh',
#  '533/24 Huỳnh Văn Bánh, Phường 14, Phú Nhuận, Hồ Chí Minh',
#  '529/86C Huỳnh Văn Bánh, Phường 14, Phú Nhuận, Hồ Chí Minh',
#  '525/230 Huỳnh Văn Bánh, Phường 14, Phú Nhuận, Hồ Chí Minh',
#  'Xí nghiệp Đầu máy Sài Gòn, phường 11, Quận 3, Hồ Chí Minh',
#  '590/F3, Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '436C/11 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '2nd Floor, 625d Cách Mạng Tháng 8, Phường 15, Quận 10, Hồ Chí Minh',
#  '623/19A Cách Mạng Tháng 8, Phường 15, Quận 10, Hồ Chí Minh',
#  '601/73/2 Cách Mạng Tháng 8, Phường 15, Quận 10, Hồ Chí Minh',
#  '132/M2/4 Tô Hiến Thành, Phường 15, Quận 10, Hồ Chí Minh',
#  '40 Nguyễn Giản Thanh, Phường 15, Quận 10, Hồ Chí Minh',
#  '138Bis To Hien Thanh Street, Ward 15, District 10,, Phường 15, Quận 10, Hồ Chí Minh',
#  '189/81C Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  'A75/6A/61 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '..Duong Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '58B Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '54/19 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '117 Hồng Hà, Phường 2, Tân Bình, Hồ Chí Minh',
#  '121/33 Hồng Hà, Phường 9, Tân Bình, Hồ Chí Minh',
#  '121/25, Hồng Hà, Phường 2, Quận Tân Bình, Phường 2, Tân Bình, Hồ Chí Minh',
#  '128 Hồng Hà, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '325 Phổ Quang, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '122 Phổ Quang, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '119 Phổ Quang, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '119 Phổ Quang, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  'Unnamed Road, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  'Unnamed Road, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '202 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '202 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '164A/20 Nguyễn Văn Trỗi, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '305/9 Nguyen Trong Tuyen Street,Ward 10, Phu Nhuan District, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '11/1 Đặng Văn Ngữ, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '17ABis Đặng Văn Ngữ, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '33A Đặng Văn Ngữ, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '190 Đường Lê Văn Sỹ, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '231/7 Đường Lê Văn Sỹ, Phường 14, Phú Nhuận, Hồ Chí Minh',
#  '523 Huỳnh Văn Bánh, Phường 14, Phú Nhuận, Hồ Chí Minh',
#  '491/51 Huỳnh Văn Bánh, Phường 13, Phú Nhuận, Hồ Chí Minh',
#  '489A/23A/154 Huỳnh Văn Bánh, Phường 13, Phú Nhuận, Hồ Chí Minh',
#  '1115 Hoàng Sa, Phường 11, Quận 3, Hồ Chí Minh',
#  '540/21 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '462B/101 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '502 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '601/12/18 Cách Mạng Tháng 8, Phường 15, Quận 10, Hồ Chí Minh',
#  '595/5F Cách Mạng Tháng 8, Phường 15, Quận 10, Hồ Chí Minh',
#  '132/11 Tô Hiến Thành, Phường 15, Quận 10, Hồ Chí Minh',
#  '132/1B/31 Tô Hiến Thành, Phường 15, Quận 10, Hồ Chí Minh',
#  '200 Tô Hiến Thành, Phường 15, Quận 10, Hồ Chí Minh',
#  '189/81C Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '159/43/11B Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '129/9 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '74/19A Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '74/62 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  'Ngã tư Bạch Đằng, phường 9, Phú Nhuận, Hồ Chí Minh',
#  '121/33 Hồng Hà, Phường 9, Tân Bình, Hồ Chí Minh 736464',
#  '119 Hồng Hà, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '130 Hồng Hà, Phường 9, Phú Nhuận, Hồ Chí Minh 700000',
#  '156 Phổ Quang, Phường 9, Phú Nhuận, Hồ Chí Minh 700000',
#  '112.3 Phổ Quang Phường 09 Quận Phú Nhuận TP.HCM, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '112.3 Phổ Quang Phường 09, Phú Nhuận, Hồ Chí Minh',
#  'Unnamed Road, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  'Unnamed Road, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  'Unnamed Road, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '202 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '200m Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '211/10 Hoàng Văn Thụ, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '269A Nguyễn Trọng Tuyển, Phường 10, Phú Nhuận, Hồ Chí Minh 70000',
#  '271F2 Nguyễn Trọng Tuyển, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '18BIS Hoàng Diệu, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '33/5 Đặng Văn Ngữ, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '184/4 Đường Lê Văn Sỹ, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '189 Đường Lê Văn Sỹ, Phường 14, Phú Nhuận, Hồ Chí Minh',
#  '479 Huỳnh Văn Bánh, Phường 13, Phú Nhuận, Hồ Chí Minh',
#  '489A/21/29 Huỳnh Văn Bánh, Phường 13, Phú Nhuận, Hồ Chí Minh',
#  '489A/23/203 Huỳnh Văn Bánh, Phường 13, Phú Nhuận, Hồ Chí Minh',
#  'Cầu Số 5, phường 13, Phú Nhuận, Hồ Chí Minh',
#  '239/67/78 Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '472/66A Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '462A/23 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '595 Cách Mạng Tháng 8, Phường 15, Quận 10, Hồ Chí Minh',
#  '575/18 Cách Mạng Tháng 8, Phường 15, Quận 10, Hồ Chí Minh',
#  '116/10/19 Tô Hiến Thành, Phường 15, Quận 10, Hồ Chí Minh',
#  '160 Tô Hiến Thành, Phường 15, Quận 10, Hồ Chí Minh',
#  '133/3/21 Tô Hiến Thành, Phường 13, Quận 10, Hồ Chí Minh',
#  '440 Nguyễn Văn Công, Phường 3, Tân Bình, Hồ Chí Minh',
#  '3/33A Đường số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '159/1B1 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '151 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '112/23 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  '112/27 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  'Khu trò chơi trẻ em, Đặng Văn Sâm, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  'Công viên Gia Định - Khu B, Hoàng Minh Giám, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '8 Hoàng Minh Giám, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '12 Hoàng Minh Giám, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '21/6 Hoàng Minh Giám, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '158 Phổ Quang, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '158 Phổ Quang, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  'Unnamed Road, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  'Unnamed Road, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  'Unnamed Road, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  'Trương Quốc Dung, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '200 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '205/18 Hoàng Văn Thụ, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '89/1B Nguyễn Trọng Tuyển, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '12/8 Hoàng Diệu, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '7Bis Hoàng Diệu, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '74 Trương Quốc Dung, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '182/28I Đường Lê Văn Sỹ, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '{{Province, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '137/14 Đường Lê Văn Sỹ, Phường 13, Phú Nhuận, Hồ Chí Minh',
#  '137/83 Đường Lê Văn Sỹ, Phường 13, Phú Nhuận, Hồ Chí Minh',
#  '115/114B Đường Lê Văn Sỹ, Phường 13, Phú Nhuận, Hồ Chí Minh',
#  '1122 Trường Sa, Phường 13, Quận 3, Hồ Chí Minh',
#  '239/79 Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '436A/7 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '444/16 Cách Mạng Tháng 8, Phường 11, Quận 3, Hồ Chí Minh',
#  '571/1A Cách Mạng Tháng 8, Phường 15, Quận 10, Hồ Chí Minh',
#  '571/17/33 Cách Mạng Tháng 8, Phường 15, Quận 10, Hồ Chí Minh',
#  '575/103 Cách Mạng Tháng 8, Phường 15, Quận 10, Hồ Chí Minh',
#  '134/1 Tô Hiến Thành, Phường 13, Quận 10, Hồ Chí Minh',
#  '133/24E Tô Hiến Thành, Phường 13, Quận 10, Hồ Chí Minh',
#  '133/6/7 Tô Hiến Thành, Phường 13, Quận 10, Hồ Chí Minh',
#  '121/927A Đường số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '498 Nguyễn Văn Công, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '3/18A Đường số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '179 Đường Bạch Đằng, Phường 2, Tân Bình, Hồ Chí Minh',
#  'Giữa công viên Gia Định, Phường 3, Gò Vấp, Hồ Chí Minh',
#  'Khu C - Công viên Gia Định, Nguyễn Kiệm, Phường 3, Gò Vấp, Hồ Chí Minh',
#  'Đặng Văn Sâm, Phường 3, Tân Bình, Hồ Chí Minh',
#  'Unnamed Road, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  'Cuối công viên Gia Định, phường 9, Phú Nhuận, Hồ Chí Minh',
#  '139 Hồng Hà, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '162 Đào Duy Anh, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '287/17 Đào Duy Anh, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  'Số 7 Hoàng Minh Giám, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  'Unnamed Road, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '43 Hồ Văn Huê, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '19/54 Hồ Văn Huê, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '198/B15 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '198 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '197/9 Hoàng Văn Thụ, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '254 Nguyễn Trọng Tuyển, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '47 Trương Quốc Dung, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '68 Trương Quốc Dung, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '76A/53B Trần Hữu Trang, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '107 Trần Hữu Trang, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '111/13 Trần Hữu Trang, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '102 Đường Lê Văn Sỹ, Phường 13, Phú Nhuận, Hồ Chí Minh',
#  '95/31 Đường Lê Văn Sỹ, Phường 13, Phú Nhuận, Hồ Chí Minh',
#  '453/97 Đường Lê Văn Sỹ, Phường 12, Quận 3, Hồ Chí Minh',
#  '1076 Trường Sa, Phường 12, Quận 3, Hồ Chí Minh',
#  '237/98 Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '237/24 Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '430/51 Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  '412C Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  '50/16 Tô Hiến Thành, Phường 15, Quận 10, Hồ Chí Minh',
#  '79/12 bis Tô Hiến Thành, Phường 13, Quận 10, Hồ Chí Minh',
#  '521/100Bis Cách Mạng Tháng 8, Phường 13, Quận 10, Hồ Chí Minh',
#  '133/5/12E Tô Hiến Thành, Phường 13, Quận 10, Hồ Chí Minh',
#  '322e Hoà Hưng, Phường 13, Quận 10, Hồ Chí Minh',
#  '123/955A Đường số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '33/16G Đường số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '2 Nguyễn Văn Công, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '11/7B Đường số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  'A42 Đường số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  'Khu C - Công viên Gia Định, Nguyễn Kiệm, Phường 3, Gò Vấp, Hồ Chí Minh',
#  'Ngã ba Đặng Văn Sâm, phường 9, Phú Nhuận, Hồ Chí Minh',
#  '3 Hoàng Minh Giám, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '5 Hoàng Minh Giám, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '131 Hồng Hà, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '88/1B Đào Duy Anh, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '104 Đào Duy Anh, Phường 9, Quận Phú Nhuận, Tp. Hồ Chí Minh, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  'Số 7 Hoàng Minh Giám, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '003, Khu Phố Mỹ Tú, H31, Phường Tân Phong, Quận 7, Thành Phố Hồ Chí Minh, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '43 Hồ Văn Huê, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '19/54 Hồ Văn Huê, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '194 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '194 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '200/10 Nguyễn Trọng Tuyển, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '208 Nguyễn Trọng Tuyển, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '94 Nguyễn Văn Trỗi, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '179/22/24B Đường Mai Văn Ngọc, Phường 10, Phú Nhuận, Hồ Chí Minh',
#  '179/42 Đường Mai Văn Ngọc, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '212 Nguyễn Đình Chính, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '207/5/2 Nguyễn Đình Chính, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '68/7 Đường Lê Văn Sỹ, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '55/19 Đường Lê Văn Sỹ, Phường 13, Phú Nhuận, Hồ Chí Minh',
#  '453KL/8 Đường Lê Văn Sỹ, Phường 12, Quận 3, Hồ Chí Minh',
#  '453KB/94 Đường Lê Văn Sỹ, Phường 12, Quận 3, Hồ Chí Minh',
#  '205/39/72 Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '205/29 Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '436/78/23 Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  '390/1C Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  '51 Tô Hiến Thành, Phường 13, Quận 10, Hồ Chí Minh',
#  '493/95Bis Cách Mạng Tháng 8, Phường 13, Quận 10, Hồ Chí Minh',
#  '493/32N Cách Mạng Tháng 8, Phường 13, Quận 10, Hồ Chí Minh',
#  '246/42 Hoà Hưng, Phường 13, Quận 10, Hồ Chí Minh',
#  '316 Hoà Hưng, Phường 12, Quận 10, Hồ Chí Minh',
#  '157 Nguyễn Kiệm, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '115/24 Đường số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '123/951M Đường số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '371 Nguyễn Kiệm, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '52B Đường số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  'Vòng xoay Nguyễn Thái Sơn, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '58 Hoàng Minh Giám, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '58 Hoàng Minh Giám, Phường 3, Gò Vấp, Hồ Chí Minh',
#  'Ngã ba Đặng Văn Sâm, phường 9, Phú Nhuận, Hồ Chí Minh',
#  '3 Hoàng Minh Giám, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '139 Hồng Hà, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '336B/18A Đào Duy Anh, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '197 Đào Duy Anh, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '81/50 Hồ Văn Huê, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '81/552 Hồ Văn Huê, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '43 Hồ Văn Huê, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '19/4A Hồ Văn Huê, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '15a Hồ Văn Huê, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '188 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '159/11 Hoàng Văn Thụ, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '184 Nguyễn Trọng Tuyển, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '80 Nguyễn Văn Trỗi, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '164 Nguyễn Đình Chính, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '151B Nguyễn Đình Chính, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '29/6 Bis Trần Hữu Trang, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '216C/7A Huỳnh Văn Bánh, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '305E/125B Huỳnh Văn Bánh, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '489 Đường Lê Văn Sỹ, Phường 12, Quận 3, Hồ Chí Minh',
#  '453KA/5 Đường Lê Văn Sỹ, Phường 12, Quận 3, Hồ Chí Minh',
#  '453KA/73 Đường Lê Văn Sỹ, Phường 12, Quận 3, Hồ Chí Minh',
#  '195/43B Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '159/76 Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '177A Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '372/13A Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  '499 Cách Mạng Tháng 8, Phường 13, Quận 10, Hồ Chí Minh',
#  '493/4 Cách Mạng Tháng 8, Phường 13, Quận 10, Hồ Chí Minh',
#  '475/93 B Cách Mạng Tháng 8, Phường 13, Quận 10, Hồ Chí Minh',
#  '216/70A Hoà Hưng, Phường 13, Quận 10, Hồ Chí Minh',
#  '133/13 Hòa Hưng Tổ 5, Khu phố Khu phố 1, Phường 12, Quận 10, Hồ Chí Minh',
#  '36 Hoàng Dư Khương, Phường 12, Quận 10, Hồ Chí Minh',
#  '831 Nguyễn Kiệm, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '787 Nguyễn Kiệm, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '91 Gò Vấp 3,, Nguyễn Kiệm, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '784 Nguyễn Kiệm, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '19A Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  'A8 Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  'Đầu công viên Gia Định, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '776, Đường Nguyễn Kiệm, Phường 4, Quận Phú Nhuận, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '675 Nguyễn Kiệm, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '3 Đặng Văn Sâm, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '58 Bùi Văn Thêm, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '304/10B Đào Duy Anh, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '292 Đào Duy Anh, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '323B/11, Đường Đào Duy Anh, Phường 9, Quận Phú Nhuận, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '81 Hồ Văn Huê, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '55 Hồ Văn Huê, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '154/37 Trần Khắc Trân, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '40/12B Chiến Thắng, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '3 Chiến Thắng, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '129/3/18/13 Hoàng Văn Thụ, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '193 Nguyễn Trọng Tuyển, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '37 Nguyễn Thị Huỳnh, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '159 Nguyễn Văn Trỗi, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '135/16A Nguyễn Đình Chính, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '48/46 Hồ Biểu Chánh, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '198/5 Huỳnh Văn Bánh, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '528/15/61 Đường Lê Văn Sỹ, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '446/12N Đường Lê Văn Sỹ, Phường 14, Quận 3, Hồ Chí Minh',
#  '429/26A Đường Lê Văn Sỹ, Phường 12, Quận 3, Hồ Chí Minh',
#  '443/79D Đường Lê Văn Sỹ, Phường 12, Quận 3, Hồ Chí Minh',
#  '159 Hoàng Sa, Phường 11, Quận 3, Hồ Chí Minh',
#  '159/52/7 Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '159 Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '358/38C Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  '390/4/9, Cách Mạng Tháng Tám, Phường 10, Quận 3, Thành Phố Hồ Chí Minh, Phường 10, Quận 3, Hồ Chí Minh',
#  '463B/26 Cách Mạng Tháng 8, Phường 13, Quận 10, Hồ Chí Minh',
#  '457/128 Cách Mạng Tháng 8, Phường 13, Quận 10, Hồ Chí Minh',
#  '196 Hoà Hưng, Phường 12, Quận 10, Hồ Chí Minh',
#  '91 Hoà Hưng, Phường 12, Quận 10, Hồ Chí Minh',
#  '24/3 Hoàng Dư Khương, Phường 12, Quận 10, Hồ Chí Minh',
#  '786 Nguyễn Kiệm, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '175, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '818/1/18 Nguyễn Kiệm, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '1 Nguyễn Thái Sơn, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '52 Nguyễn Thái Sơn, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '337 Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '440/46D Nguyễn Kiệm, Phường 1, Phú Nhuận, Hồ Chí Minh 700000',
#  '778/17k Nguyễn Kiệm, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '756 Nguyễn Kiệm, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '744 Nguyễn Kiệm, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '661/3 Nguyễn Kiệm, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '704, Nguyễn Kiệm, P.4, Quận Phú Nhuận, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '597/3 Nguyễn Kiệm, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '135 Hồ Văn Huê, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '198/3 Hồ Văn Huê, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '100/156 Chiến Thắng, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '303 Đường Đỗ Tấn Phong, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '318/2 Đường Đỗ Tấn Phong, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '118 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '221B/1B Trần Huy Liệu, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '149 Nguyễn Trọng Tuyển, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '140/7H Nguyễn Đình Chính, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '68A Nguyễn Văn Trỗi, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '18/12 Hồ Biểu Chánh, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '34 Hồ Biểu Chánh, Phường 12, Phú Nhuận, Hồ Chí Minh',
#  '66 Hồ Biểu Chánh, Phường 12, Phú Nhuận, Hồ Chí Minh',
#  '102/10 Hồ Biểu Chánh, Phường 11, Phú Nhuận, Hồ Chí Minh',
#  '466/15A Đường Lê Văn Sỹ, Phường 14, Quận 3, Hồ Chí Minh',
#  '407/14 Đường Lê Văn Sỹ, Phường 12, Quận 3, Hồ Chí Minh',
#  '413 Đường Lê Văn Sỹ, Phường 12, Quận 3, Hồ Chí Minh',
#  'Secret tower , Nhieu Loc, Phường 12, Quận 3, Hồ Chí Minh',
#  '113/96- Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '113/38 Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  'Saigon Railway Station, 1 Nguyễn Thông, Phường 10, Quận 3, Hồ Chí Minh',
#  '342/5 Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  '457/20 Cách Mạng Tháng 8, Phường 13, Quận 10, Hồ Chí Minh',
#  '106/25 Hoà Hưng, Phường 13, Quận 10, Hồ Chí Minh',
#  '91/6H1 Hoà Hưng, Phường 12, Quận 10, Hồ Chí Minh',
#  '91/12 Hoà Hưng, Phường 12, Quận 10, Hồ Chí Minh',
#  'Hẻm 24 Hoàng Dư Khương, Phường 12, Quận 10, Hồ Chí Minh',
#  '786 Nguyễn Kiệm, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '175, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '1 Nguyễn Thái Sơn, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '42 Nguyễn Thái Sơn, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '68/28 Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '818/27/7A Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '782/68A Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '778/74 Nguyễn Kiệm, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '750/1bis Nguyễn Kiệm, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '744/16 Nguyễn Kiệm, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '170D Thích Quảng Đức, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '235/17 Thích Quảng Đức, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '654/10 Nguyễn Kiệm, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '562/46 Nguyễn Kiệm, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '519 Nguyễn Kiệm, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '485 Nguyễn Kiệm, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '469/64 Nguyễn Kiệm, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '94/66 Trần Khắc Chân, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '68 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '158/11 Trần Huy Liệu, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '136 Trần Huy Liệu, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '151 Trần Huy Liệu, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '125 Nguyễn Đình Chính, Phường 8, Phú Nhuận, Hồ Chí Minh',
#  '66, Đường Nguyễn Văn Trỗi, Phường 8, Quận Phú Nhuận, Phường 12, Phú Nhuận, Hồ Chí Minh',
#  '24/7 Trần Cao Vân, Phường 12, Phú Nhuận, Hồ Chí Minh',
#  '226A, Huỳnh Văn Bánh, Phường 12, Quận Phú Nhuận, Thành Phố Hồ Chí Minh, Phường 12, Phú Nhuận, Hồ Chí Minh',
#  '247/2A Huỳnh Văn Bánh, Phường 12, Phú Nhuận, Hồ Chí Minh',
#  '386/57 Đường Lê Văn Sỹ, Phường 14, Quận 3, Hồ Chí Minh',
#  '453/111KC, Lê Văn Sỹ, Phường 12, Quận 3, Thành Phố Hồ Chí Minh, Phường 13, Quận 3, Hồ Chí Minh',
#  '359/1/27B Đường Lê Văn Sỹ, Phường 13, Quận 3, Hồ Chí Minh',
#  '359/1/43D Đường Lê Văn Sỹ, Phường 13, Quận 3, Hồ Chí Minh',
#  '879 Hoàng Sa, Phường 11, Quận 3, Hồ Chí Minh',
#  '79/22A Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  'Saigon Railway Station, 1 Nguyễn Thông, Phường 10, Quận 3, Hồ Chí Minh',
#  '322/3F Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  '405 Cách Mạng Tháng 8, Phường 13, Quận 10, Hồ Chí Minh',
#  '84A Hoà Hưng, Phường 13, Quận 10, Hồ Chí Minh',
#  '83 Hoà Hưng, Phường 12, Quận 10, Hồ Chí Minh',
#  'Hẻm 91 Hoà Hưng, Phường 12, Quận 10, Hồ Chí Minh',
#  'Hẻm 24 Hoàng Dư Khương, Phường 12, Quận 10, Hồ Chí Minh',
#  'No. 118, Nguyen Thai Son Street, Ward 3, Go Vap District, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '112 Nguyễn Thái Sơn, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '76, Nguyen Thai Son Street, Ward 3, Go Vap District, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '90 Nguyễn Thái Sơn, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '163/16 Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '818/51 Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '818/55/14B Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '819/37A Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '229/181 Chiến Thắng, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '166A/19 Chiến Thắng, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '166/39A Chiến Thắng, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '187 Thích Quảng Đức, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  'F29 Nguyễn Đình Chiểu, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '34 Lê Tự Tài, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '25 Nguyễn Đình Chiểu, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '440/11D Nguyễn Kiệm, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '447 Nguyễn Kiệm, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '413/14 Nguyễn Kiệm, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '30 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '33D Trần Khắc Trân, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '91 Nguyễn Trọng Tuyển, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '100A Nguyễn Đình Chính, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '117C Nguyễn Đình Chính, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '121B Nguyễn Văn Trỗi, Phường 12, Phú Nhuận, Hồ Chí Minh',
#  '158/12, Tran Huy Lieu Street, Ward 12, Phu Nhuan District, Phường 12, Phú Nhuận, Hồ Chí Minh',
#  '18 Trần Huy Liệu, Phường 12, Phú Nhuận, Hồ Chí Minh',
#  '103/2 Trần Quang Diệu, Phường 14, Quận 3, Hồ Chí Minh',
#  '101 Trần Quang Diệu, Phường 14, Quận 3, Hồ Chí Minh',
#  '386/6 Đường Lê Văn Sỹ, Phường 14, Quận 3, Hồ Chí Minh',
#  '331/8B Đường Lê Văn Sỹ, Phường 13, Quận 3, Hồ Chí Minh',
#  '339/17 Đường Lê Văn Sỹ, Phường 13, Quận 3, Hồ Chí Minh',
#  '948 Trường Sa, Phường 13, Quận 3, Hồ Chí Minh',
#  '75/58 Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '1 Nguyễn Thông, Phường 10, Quận 3, Hồ Chí Minh',
#  '280/19 Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  '276BIS Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  '23/27 Hoà Hưng, Phường 12, Quận 10, Hồ Chí Minh',
#  'Hẻm 377 Cách Mạng Tháng Tám, Phường 12, Quận 10, Hồ Chí Minh',
#  'Hẻm 24 Hoàng Dư Khương, Phường 12, Quận 10, Hồ Chí Minh',
#  'Hẻm 24 Hoàng Dư Khương, Phường 12, Quận 10, Hồ Chí Minh',
#  '150 Nguyễn Thái Sơn, Phường 4, Gò Vấp, Hồ Chí Minh',
#  'Hẻm 31/30 Lê Lai, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '112/25/3 Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '112/54-56 Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '146/44/2 Đường Trương Đăng Quế, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '820/74/4C Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '75/2 Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '820/100/1 Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '228/84 Chiến Thắng, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '100/391A Chiến Thắng, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '100/347A Chiến Thắng, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '100/5C Thích Quảng Đức, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '163/20 Thích Quảng Đức, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '75/4A Nguyễn Đình Chiểu, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '58/2A Nguyễn Đình Chiểu, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '468/30/3E Nguyễn Kiệm, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '468/26/23 Nguyễn Kiệm, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '388/4 Nguyễn Kiệm, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '2 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh',
#  '48D Trần Khắc Trân, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '18 Nguyễn Đình Chính, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '130/3 Nguyễn Đình Chính, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '108 Duy Tân, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '40 Nguyễn Văn Trỗi, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '108/19 Huỳnh Văn Bánh, Phường 12, Phú Nhuận, Hồ Chí Minh',
#  '163/11A Huỳnh Văn Bánh, Phường 14, Quận 3, Hồ Chí Minh',
#  '136/15B Trần Quang Diệu, Phường 12, Phú Nhuận, Hồ Chí Minh',
#  '80/16 Trần Quang Diệu, Phường 14, Quận 3, Hồ Chí Minh',
#  '18/5 Trần Quang Diệu, Phường 14, Quận 3, Hồ Chí Minh',
#  '13 Trần Quang Diệu, Phường 13, Quận 3, Hồ Chí Minh',
#  '8B Trần Quang Diệu, Phường 13, Quận 3, Hồ Chí Minh',
#  '720, Đường Trường Sa, Phường 14, Quận 3, Phường 13, Quận 3, Hồ Chí Minh',
#  '49/7N Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '96/34 Nguyễn Thông, Phường 10, Quận 3, Hồ Chí Minh',
#  '240/46B Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  '258/5 Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  '317/97 Cách Mạng Tháng 8 Tổ 17, Khu phố Khu phố, Phường 12, Quận 10, Hồ Chí Minh',
#  '285/5/5A Tổ Cách Mạng Tháng 8, Khu phố 23, Phường 12, Quận 10, Hồ Chí Minh',
#  '285/21/4 Tổ Cách Mạng Tháng 8, Khu phố 23A, Phường 12, Quận 10, Hồ Chí Minh',
#  '285/58 Hẻm 285 Cách Mạng Tháng Tám, Phường 12, Quận 10, Hồ Chí Minh',
#  '96/1C Lê Lợi, Phường 4, Gò Vấp, Hồ Chí Minh',
#  '106/4 Đường số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '173 Phạm Văn Đồng, Phường 3, Gò Vấp, Hồ Chí Minh 700000',
#  '123/9 Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '131/8 Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '86 Đường Trương Đăng Quế, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '133/877 Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '77/739 Đường Số 7, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '247/9 Hoàng Hoa Thám, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '100/523A Chiến Thắng, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '100/156N Chiến Thắng, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '98/8 Thích Quảng Đức, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '97 Thích Quảng Đức, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '89 Nguyễn Đình Chiểu, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '68 Phan Xích Long, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '43/5/30 Phan Xích Long, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '178/4 Phan Đăng Lưu, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '206 Phan Đăng Lưu, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '215D/12 Đoàn Thị Điểm, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '318 Phan Đình Phùng, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '11/12 Nguyễn Trọng Tuyển, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '42/3 Duy Tân, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '101/34 Duy Tân, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '98 Huỳnh Văn Bánh, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '35 Nguyễn Văn Trỗi, Phường 14, Quận 3, Hồ Chí Minh',
#  '18c Lê Quý Đôn, Phường 14, Phú Nhuận, Hồ Chí Minh 700000',
#  '108/65 Trần Quang Diệu, Phường 14, Quận 3, Hồ Chí Minh',
#  '40/61 Trần Quang Diệu, Phường 14, Quận 3, Hồ Chí Minh',
#  '18//34/1 Trần Quang Diệu, Phường 14, Quận 3, Hồ Chí Minh',
#  '264 Đường Lê Văn Sỹ, Phường 14, Quận 3, Hồ Chí Minh',
#  '207/63A Đường Lê Văn Sỹ, Phường 13, Quận 3, Hồ Chí Minh',
#  '91/16 Trần Quang Diệu, Phường 13, Quận 3, Hồ Chí Minh',
#  '47A/58 Trần Văn Đang, Phường 11, Quận 3, Hồ Chí Minh',
#  '96/10 Nguyễn Thông, Phường 10, Quận 3, Hồ Chí Minh',
#  '40/100D Nguyễn Thông, Phường 9, Quận 3, Hồ Chí Minh',
#  '210/16A Cách Mạng Tháng 8 P10, Quận 3, 3, Phường 10, Quận 3, Hồ Chí Minh',
#  '303a Cách Mạng Tháng 8, Phường 12, Quận 10, Hồ Chí Minh',
#  '285/3/6 Tổ Cách Mạng Tháng 8, Khu phố 23, Phường 12, Quận 10, Hồ Chí Minh',
#  '285 Hẻm 285 Cách Mạng Tháng Tám, Phường 12, Quận 10, Hồ Chí Minh',
#  '285/F1/4BIS C¸ch M¹ng Th¸ng 8, Phường 12, Quận 10, Hồ Chí Minh',
#  '142/7 Lê Lợi, Phường 4, Gò Vấp, Hồ Chí Minh',
#  '16 Lê Lai, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '168/28 Phạm Văn Đồng, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '118 Đường Số 7, Phường 3, Gò Vấp, Hồ Chí Minh',
#  '640/70 Đường Số 7, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '122/16/7 Đường Số 7, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '73 Đường Trương Đăng Quế, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '110/32 Đường Số 7, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '100/233A Hoàng Hoa Thám, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '100/594B Nguyễn Thượng Hiền, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '252/2 Nguyễn Thượng Hiền, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '86/23D Thích Quảng Đức, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '68/23 Thích Quảng Đức, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '99/11 Nguyễn Đình Chiểu, Phường 4, Phú Nhuận, Hồ Chí Minh',
#  '6/29A Phan Xích Long, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '27 Phan Xích Long, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '162/17 Phan Đăng Lưu, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '389/3 Cô Giang, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '215/27/1C Đoàn Thị Điểm, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '270/67 Phan Đình Phùng, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '96/94 đường Phan Đình Phùng, phường 2, quận Phú Nhuận, thành phố Hồ Chí Minh, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '28/2 Huỳnh Văn Bánh, Phường 15, Phú Nhuận, Hồ Chí Minh',
#  '61/12 Huỳnh Văn Bánh, Phường 17, Phú Nhuận, Hồ Chí Minh',
#  '95/32 Huỳnh Văn Bánh, Phường 17, Phú Nhuận, Hồ Chí Minh',
#  '14 Nguyễn Văn Trỗi, Phường 17, Phú Nhuận, Hồ Chí Minh',
#  '108/62B Trần Quang Diệu, Phường 14, Quận 3, Hồ Chí Minh',
#  '108/38HA Trần Quang Diệu, Phường 14, Quận 3, Hồ Chí Minh',
#  '18/163D Trần Quang Diệu, Phường 14, Quận 3, Hồ Chí Minh',
#  '284/49 Đường Lê Văn Sỹ, Phường 14, Quận 3, Hồ Chí Minh',
#  '264M Đường Lê Văn Sỹ, Phường 14, Quận 3, Hồ Chí Minh',
#  '207/27 Đường Lê Văn Sỹ, Phường 13, Quận 3, Hồ Chí Minh',
#  '25 Trường Sa, Phường 13, Quận 3, Hồ Chí Minh',
#  '88/79/15 Bà Huyện Thanh Quan, Phường 9, Quận 3, Hồ Chí Minh',
#  '11 Trần Văn Đang, Phường 9, Quận 3, Hồ Chí Minh',
#  '86 Nguyễn Thông, Phường 9, Quận 3, Hồ Chí Minh',
#  '151 Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  '184 Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  '28330 Hẻm 283 CáCh Mạng tháng Tám, Phường 12, Quận 10, Hồ Chí Minh',
#  '75 Hẻm 283 CáCh Mạng tháng Tám, Phường 12, Quận 10, Hồ Chí Minh',
#  '118 Ba Tháng Hai, Phường 12, Quận 10, Hồ Chí Minh',
#  '113/10/4 Lê Lợi, Phường 4, Gò Vấp, Hồ Chí Minh',
#  '127/11A Lê Lai, Phường 4, Gò Vấp, Hồ Chí Minh',
#  '144/26 Đường số 7, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '98/16/11 Đường số 7, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '102 Đường số 7, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '136 Nguyễn Thượng Hiền, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '188/32 Đường Số 7, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '89E Nguyễn Thượng Hiền, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '274 Hoàng Hoa Thám, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '192 Nguyễn Thượng Hiền, Phường 6, Bình Thạnh, Hồ Chí Minh',
#  '181/5 Nguyễn Thượng Hiền, Phường 6, Bình Thạnh, Hồ Chí Minh',
#  '86/4/10I Nguyễn Thượng Hiền, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '56/38/2E Thích Quảng Đức, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '86/19/18 Thích Quảng Đức, Phường 5, Quận Phú Nhuận',
#  '3/12/2D Thích Quảng Đức, Phường 3, Phú Nhuận, Hồ Chí Minh',
#  '143/12 Phan Đăng Lưu, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '72 Phan Xích Long, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '401/1 Cô Giang, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '379/1 Cô Giang, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '270/232 Phan Đình Phùng, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '155/2 Cô Bắc, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '198 Phan Đình Phùng, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '39/20/2 Huỳnh Văn Bánh, Phường 17, Phú Nhuận, Hồ Chí Minh',
#  '103 Cao Thắng, Phường 17, Phú Nhuận, Hồ Chí Minh',
#  '83 Cao Thắng, Phường 17, Phú Nhuận, Hồ Chí Minh',
#  '541a Hoàng Sa, Phường 14, Quận 3, Hồ Chí Minh',
#  '547 Hoàng Sa, Phường 14, Quận 3, Hồ Chí Minh',
#  '220 Hẻm 220 Lê Văn Sỹ, Phường 14, Quận 3, Hồ Chí Minh',
#  '262/11B2 Đường Lê Văn Sỹ, Phường 14, Quận 3, Hồ Chí Minh',
#  '220/11/13 Đường Lê Văn Sỹ, Phường 14, Quận 3, Hồ Chí Minh',
#  '886 Trường Sa, Phường 13, Quận 3, Hồ Chí Minh',
#  '16/79BIS Kỳ Đồng, Phường 9, Quận 3, Hồ Chí Minh',
#  '177/7 Trương Định, Phường 9, Quận 3, Hồ Chí Minh',
#  '88/40 Bà Huyện Thanh Quan, Phường 9, Quận 3, Hồ Chí Minh',
#  '62/16 Rạch Bùng Binh, Phường 9, Quận 3, Hồ Chí Minh',
#  '65 Lý Chính Thắng, Phường 9, Quận 3, Hồ Chí Minh',
#  '134/1/8 Cách Mạng Tháng 8, Phường 10, Quận 3, Hồ Chí Minh',
#  'Viettel Tower, 285 Cách Mạng Tháng 8, Phường 12, Quận 10, Hồ Chí Minh',
#  'Căn số 5, đường số 8, Khu Dân cư Hà Đô, 118 Đường 3 Tháng 2, Phường 12, Quận 10, Hồ Chí Minh',
#  '116f Ba Tháng Hai, Phường 12, Quận 10, Hồ Chí Minh',
#  '199 Phạm Văn Đồng, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '441 Nguyễn Bỉnh Khiêm, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '94H Đường số 7, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '77 Trần Bình Trọng, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '55/6 Nguyễn Thượng Hiền, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '10 I Nguyễn Trung Trực, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '12K Nguyễn Trung Trực, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '101/13 Nguyễn Thượng Hiền, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '248/10 Hoàng Hoa Thám, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '189/13 Hoàng Hoa Thám, Phường 6, Bình Thạnh, Hồ Chí Minh',
#  '153/62 Nguyễn Thượng Hiền, Phường 6, Bình Thạnh, Hồ Chí Minh',
#  '243b Nguyễn Thượng Hiền, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '20/25C Thích Quảng Đức, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '92 Phan Đăng Lưu, Phú Nhuận, Hồ Chí Minh',
#  '135 Phùng Văn Cung, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '131Bis Phan Đăng Lưu, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '448/5 Phùng Văn Cung, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '412/1 Cô Giang, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '371/3A Cô Giang, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '270/116 Phan Đình Phùng, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '71B Cô Giang, Phường 1, Phú Nhuận, Hồ Chí Minh',
#  '2/98 Cô Giang, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '130/2 Cao Thắng, Phường 17, Phú Nhuận, Hồ Chí Minh',
#  '10 Đào Duy Từ, Phường 17, Phú Nhuận, Hồ Chí Minh',
#  '503 Hoàng Sa, Phường 8, Quận 3, Hồ Chí Minh',
#  '384 Nam Kỳ Khởi Nghĩa, Phường 8, Quận 3, Hồ Chí Minh',
#  '331/5 Nam Kỳ Khởi Nghĩa, Phường 14, Quận 3, Hồ Chí Minh',
#  '611 Hoàng Sa, Phường 14, Quận 3, Hồ Chí Minh',
#  '812/23, Quận 3, Hồ Chí Minh',
#  '858 Trường Sa, Phường 14, Quận 3, Hồ Chí Minh',
#  '184 Trần Quốc Thảo, Phường 14, Quận 3, Hồ Chí Minh',
#  '14 Kỳ Đồng, Phường 9, Quận 3, Hồ Chí Minh',
#  '16/6A Kỳ Đồng, Phường 9, Quận 3, Hồ Chí Minh',
#  '16A, Kỳ Đồng, Phường 9, Quận 3, Thành Phố Hồ Chí Minh, Phường 9, Quận 3, Hồ Chí Minh',
#  '25a Kỳ Đồng, Phường 9, Quận 3, Hồ Chí Minh 70000',
#  '56a Nguyễn Thông, Phường 9, Quận 3, Hồ Chí Minh',
#  '252/22 Lý Chính Thắng, Phường 9, Quận 3, Hồ Chí Minh',
#  '10, 12 Đường 3 Tháng 2, Phường 12, Quận 10, Hồ Chí Minh',
#  '23a Ba Tháng Hai, Phường 11, Quận 10, Hồ Chí Minh',
#  '3C Đường 3 Tháng 2, Phường 11, Quận 10, Hồ Chí Minh',
#  '487/34 Lê Quang Định, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '38 Lê Quang Định, Phường 1, Bình Thạnh, Hồ Chí Minh',
#  '441/11/43 Đường số 7, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '26 Nguyễn Thượng Hiền, Gò Vấp, Hồ Chí Minh',
#  '63 Trần Bình Trọng, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '6C 1 Nguyễn Trung Trực, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '21 Nguyễn Trung Trực, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '220/96 Hoàng Hoa Thám, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '220/12 Hoàng Hoa Thám, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '187/4 Hoàng Hoa Thám, Phường 6, Bình Thạnh, Hồ Chí Minh',
#  'Số 47A1, Nguyễn Văn Đậu, Phường 6, Quận Bình Thạnh, Phường 6, Bình Thạnh, Hồ Chí Minh',
#  '45/280 Nguyễn Văn Đậu, Phường 6, Bình Thạnh, Hồ Chí Minh',
#  '72/19/17A Phan Đăng Lưu, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '74/7/3 Phan Đăng Lưu, Phường 7, Phú Nhuận, Hồ Chí Minh',
#  '10 Ký Con, Phường 7, Phú Nhuận, Hồ Chí Minh',
#  '18/1A Cầm Bá Thước, Phường 7, Phú Nhuận, Hồ Chí Minh',
#  '63 Phùng Văn Cung, Phú Nhuận, Hồ Chí Minh',
#  '269 Phan Xích Long, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '362/3B Phan Xích Long, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '326/1 Cô Giang, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '478 Trường Sa, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '96/37 Phan Đình Phùng, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '68 Phan Đình Phùng, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '61/1C Phan Đình Phùng, Phường 17, Phú Nhuận, Hồ Chí Minh',
#  '62/135/49 Lý Chính Thắng, Phường 8, Quận 3, Hồ Chí Minh',
#  '380/2A Nam Kỳ Khởi Nghĩa, Phường 8, Quận 3, Hồ Chí Minh',
#  '291 Nam Kỳ Khởi Nghĩa, Phường 14, Quận 3, Hồ Chí Minh',
#  '627 Hoàng Sa, Phường 14, Quận 3, Hồ Chí Minh',
#  '818 Trường Sa, Phường 14, Quận 3, Hồ Chí Minh',
#  '150/45 Lý Chính Thắng, Phường 14, Quận 3, Hồ Chí Minh',
#  '128/7/3 Trần Quốc Thảo, Phường 14, Quận 3, Hồ Chí Minh',
#  '10D Kỳ Đồng, Phường 9, Quận 3, Hồ Chí Minh',
#  '15 Kỳ Đồng, Phường 9, Quận 3, Hồ Chí Minh',
#  '80/10 Bà Huyện Thanh Quan, Phường 9, Quận 3, Hồ Chí Minh',
#  '78 Bà Huyện Thanh Quan, Phường 9, Quận 3, Hồ Chí Minh',
#  '216 Lý Chính Thắng, Phường 9, Quận 3, Hồ Chí Minh',
#  '278A Võ Thị Sáu, Phường 7, Quận 3, Hồ Chí Minh',
#  '126 Cách Mạng Tháng 8, Phường 7, Quận 3, Hồ Chí Minh',
#  '12a Nguyễn thượng hiền Tổ 1 Khu phố 1, Phường 11, Quận 10, Hồ Chí Minh',
#  '322bis Điện biên phủ Tổ 3 Khu phố 1, Phường 11, Quận 10, Hồ Chí Minh',
#  '473A Đường số 7, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '26 Nguyễn Thượng Hiền, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '449/24 Nguyễn Thượng Hiền, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '62/12 Trần Bình Trọng, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '49 Trần Bình Trọng, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '47/8A Trần Bình Trọng, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '220/118E Hoàng Hoa Thám, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '200/28 Hoàng Hoa Thám, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '163/7 Hoàng Hoa Thám, Phường 6, Bình Thạnh, Hồ Chí Minh',
#  '47AA5 Nguyễn Văn Đậu, Phường 6, Bình Thạnh, Hồ Chí Minh',
#  '35 Nguyễn Văn Đậu, Phường 6, Bình Thạnh, Hồ Chí Minh',
#  '4th Floor, 72/24 Phan Đăng Lưu, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '54 Phan Đăng Lưu, Phường 7, Phú Nhuận, Hồ Chí Minh',
#  '3/6 Phan Tây Hồ, Phường 7, Phú Nhuận, Hồ Chí Minh',
#  '55/3 Phùng Văn Cung, Phường 7, Phú Nhuận, Hồ Chí Minh',
#  '65/2 Phùng Văn Cung, Phường 7, Phú Nhuận, Hồ Chí Minh',
#  '93A Phan Xích Long, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '68 Hoa Đào, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '420 Trường Sa, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '212/194 Nguyễn Hữu Cảnh, Tân Định, Quận 1, Hồ Chí Minh',
#  '212/170/56 Nguyễn Hữu Cảnh, Tân Định, Quận 1, Hồ Chí Minh',
#  '572a Trường Sa, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '41/1 Phan Đình Phùng, Phường 17, Phú Nhuận, Hồ Chí Minh',
#  '60/117/30 Lý Chính Thắng, Phường 8, Quận 3, Hồ Chí Minh',
#  '62/239 Lý Chính Thắng, Phường 8, Quận 3, Hồ Chí Minh',
#  '2880000 Nam Kỳ Khởi Nghĩa, Phường 8, Quận 3, Hồ Chí Minh',
#  '134/60 Lý Chính Thắng, Phường 14, Quận 3, Hồ Chí Minh',
#  '134/19B Lý Chính Thắng, Phường 14, Quận 3, Hồ Chí Minh',
#  '150/16/12 Lý Chính Thắng, Phường 14, Quận 3, Hồ Chí Minh',
#  '174/40 Lý Chính Thắng, Phường 14, Quận 3, Hồ Chí Minh',
#  '184/14 Lý Chính Thắng, Phường 9, Quận 3, Hồ Chí Minh',
#  '212 Ly Chinh Thang Street, Ward 9, District 3, Phường 9, Quận 3, Hồ Chí Minh',
#  '183 Lý Chính Thắng, Phường 7, Quận 3, Hồ Chí Minh',
#  '41 Ba Huyen Thanh Quan Street, Ward 6, District 3, Phường 7, Quận 3, Hồ Chí Minh',
#  '272 Võ Thị Sáu, Phường 7, Quận 3, Hồ Chí Minh',
#  '118, Ba Thang Hai Street, Ward 10, District 10, Phường 7, Quận 3, Hồ Chí Minh',
#  '46 Tú Xương, Phường 7, Quận 3, Hồ Chí Minh',
#  '331/94, Nguyen Thuong Hien Street, District 3, Phường 4, Quận 3, Hồ Chí Minh',
#  '562/1B Đường số 7, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '562/18B Đường số 7, Phường 1, Gò Vấp, Hồ Chí Minh',
#  '449/15A Lê Quang Định, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '377/78A Lê Quang Định, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '377/21 Lê Quang Định, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '19/2F Trần Bình Trọng, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '101/173A Nguyễn Văn Đậu, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '99 Nguyễn Văn Đậu, Phường 5, Bình Thạnh, Hồ Chí Minh',
#  '131 Hoàng Hoa Thám, Phường 6, Bình Thạnh, Hồ Chí Minh',
#  '52/9A Nguyễn Văn Đậu, Phường 6, Bình Thạnh, Hồ Chí Minh 700000',
#  '19/7, Đường Lam Sơn, Phường 5, Quận Phú Nhuận, Phường 6, Bình Thạnh, Hồ Chí Minh',
#  '19/21 Lam Sơn, Phường 5, Phú Nhuận, Hồ Chí Minh',
#  '95C Phan Đăng Lưu, Phường 7, Phú Nhuận, Hồ Chí Minh',
#  '167/3 Trần Kế Xương, Phường 7, Phú Nhuận, Hồ Chí Minh',
#  '51/5 Phan Tây Hồ, Phường 7, Phú Nhuận, Hồ Chí Minh',
#  '83/5 Phan Tây Hồ, Phường 7, Phú Nhuận, Hồ Chí Minh',
#  '2 Phan Xích Long, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '187 Hoa Lan, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '48, Nhieu Loc Street, Ward 2, Phu Nhuan District, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '253a Hoàng Sa, Tân Định, Quận 1, Hồ Chí Minh',
#  '212/184/6 Nguyễn Hữu Cảnh, Tân Định, Quận 1, Hồ Chí Minh',
#  '357 Hoàng Sa, Tân Định, Quận 1, Hồ Chí Minh',
#  '16, Phan Đình Phùng, Phường 4, Thị Xã Bạc Liêu, Thành Phố Cà Mau, Phường 2, Phú Nhuận, Hồ Chí Minh',
#  '475/46/36 Hai Bà Trưng, Phường 8, Quận 3, Hồ Chí Minh',
#  ...]

# %% [markdown]
# Looking good. Let's now place all this into a Pandas dataframe.

# %%
import pandas as pd

df_locations = pd.DataFrame({'Address': addresses,
                             'Latitude': latitudes,
                             'Longitude': longitudes,
                             'X': xs,
                             'Y': ys,
                             'Distance from center': distances_from_center})

df_locations.head(10)
# Out:
#                                              Address   Latitude   Longitude  \
# 0  30 Phan Thúc Duyện, Phường 4, Tân Bình, Hồ Chí...  10.806386  106.659513
# 1  6/22 Hẻm số 6 Đồ Sơn, Phường 4, Tân Bình, Hồ C...  10.805288  106.659364
# 2        27 Sầm Sơn, Phường 4, Tân Bình, Hồ Chí Minh  10.804190  106.659216
# 3  36/14 Hẻm 36 Giải Phóng, Phường 4, Tân Bình, H...  10.803092  106.659068
# 4  2/15 Hẻm số 2 Đồng Khởi, Phường 4, Tân Bình, H...  10.801995  106.658919
# 5       15 Cộng Hòa, Phường 4, Tân Bình, Hồ Chí Minh  10.800897  106.658771
# 6  51 Nguyễn Thái Bình, Phường 4, Tân Bình, Hồ Ch...  10.799800  106.658623
# 7  308/5 Hoàng Văn Thụ, Phường 4, Tân Bình, Hồ Ch...  10.798702  106.658475
# 8  40a, 40B Út Tịch, Phường 4, Tân Bình, Hồ Chí Minh  10.797605  106.658326
# 9  437/13- 437/15 Hoàng Văn Thụ, Phường 4, Tân Bì...  10.796508  106.658178
#
#               X             Y  Distance from center
# 0  1.521749e+07  1.088831e+07          11945.259904
# 1  1.521809e+07  1.088831e+07          11793.609888
# 2  1.521869e+07  1.088831e+07          11670.871184
# 3  1.521929e+07  1.088831e+07          11577.963300
# 4  1.521989e+07  1.088831e+07          11515.608286
# 5  1.522049e+07  1.088831e+07          11484.303818
# 6  1.522109e+07  1.088831e+07          11484.303818
# 7  1.522169e+07  1.088831e+07          11515.608286
# 8  1.522229e+07  1.088831e+07          11577.963300
# 9  1.522289e+07  1.088831e+07          11670.871184

# %%
df_locations.sort_values(by=['Distance from center'])
# Out:
#                                                 Address   Latitude  \
# 717   48D Trần Khắc Trân, Phường 15, Phú Nhuận, Hồ C...  10.798086
# 718   18 Nguyễn Đình Chính, Phường 15, Phú Nhuận, Hồ...  10.796989
# 758   11/12 Nguyễn Trọng Tuyển, Phường 15, Phú Nhuận...  10.796861
# 757   318 Phan Đình Phùng, Phường 1, Phú Nhuận, Hồ C...  10.797958
# 678   91 Nguyễn Trọng Tuyển, Phường 15, Phú Nhuận, H...  10.797118
# ...                                                 ...        ...
# 1446  27/75 Điện Biên Phủ, Phường 15, Bình Thạnh, Hồ...  10.797304
# 1290  387 Chu Văn An, Phường 12, Bình Thạnh, Hồ Chí ...  10.811388
# 1319       22 Võ Văn Tần, Phường 6, Quận 3, Hồ Chí Minh  10.779575
# 1416  24 Phan Chu Trinh, Phường 14, Bình Thạnh, Hồ C...  10.804149
# 1433       28 Mạc Đĩnh Chi, Đa Kao, Quận 1, Hồ Chí Minh  10.785501
#
#        Longitude             X             Y  Distance from center
# 717   106.679919  1.522049e+07  1.089974e+07            303.951092
# 718   106.679769  1.522109e+07  1.089974e+07            303.951092
# 758   106.680730  1.522109e+07  1.090026e+07            558.229748
# 757   106.680880  1.522049e+07  1.090026e+07            558.229748
# 678   106.678808  1.522109e+07  1.089923e+07            642.769073
# ...          ...           ...           ...                   ...
# 1446  106.702326  1.521929e+07  1.091170e+07          11996.448330
# 1290  106.697418  1.521209e+07  1.090806e+07          12000.005551
# 1319  106.693024  1.522949e+07  1.090806e+07          12000.005551
# 1416  106.701316  1.521569e+07  1.091066e+07          12000.679321
# 1433  106.698733  1.522589e+07  1.091066e+07          12000.679321
#
# [1452 rows x 6 columns]

# %% [markdown]
# ...and let's now save/persist this data into local file.

# %%
df_locations.to_pickle('./locations.pkl')

# %%
df_locations.shape
# Out:
# (1452, 6)

# %% [markdown]
# # Foursquare
#
# Now that we have our location candidates, let's use Foursquare API to get info on restaurants in each area.
#
# We're interested in venues in 'food' category (include coffee shops, cafes). We will include in our list only venues that have 'coffee' in the category name.

# %%
# Category IDs corresponding to coffee shop were taken from Foursquare web site 
#(https://developer.foursquare.com/docs/resources/categories):

food_category = '4d4b7105d754a06374d81259' # 'Root' category for all food-related venues

coffee_shop_categories = ['4bf58dd8d48988d16d941735',
                                 '4bf58dd8d48988d1e0931735',
                                 '4bf58dd8d48988d1f0941735',
                                 '4bf58dd8d48988d1e0931735',
                                 '5665c7b9498e7d8a4f2c0f06',
                                 '54f4ba06498e2cf5561da814',
                                 '4bf58dd8d48988d18d941735',
                                ]

def is_restaurant(categories, specific_filter=None):
    restaurant_words = ['restaurant', 'diner', 'taverna', 'steakhouse']
    restaurant = False
    specific = False
    for c in categories:
        category_name = c[0].lower()
        category_id = c[1]
        for r in restaurant_words:
            if r in category_name:
                restaurant = True
        if 'fast food' in category_name:
            restaurant = False
        if not(specific_filter is None) and (category_id in specific_filter):
            specific = True
            restaurant = True
    return restaurant, specific

def get_categories(categories):
    return [(cat['name'], cat['id']) for cat in categories]

def format_address(location):
    address = ', '.join(location['formattedAddress'])
    #address = address.replace(', Deutschland', '')
    address = address.replace(', Vietnam', '')
    return address

def get_venues_near_location(lat, lon, category, client_id, client_secret, radius=500, limit=100):
    version = '20180724'
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}'.format(
        client_id, client_secret, version, lat, lon, category, radius, limit)
    try:
        results = requests.get(url).json()['response']['groups'][0]['items']
        venues = [(item['venue']['id'],
                   item['venue']['name'],
                   get_categories(item['venue']['categories']),
                   (item['venue']['location']['lat'], item['venue']['location']['lng']),
                   format_address(item['venue']['location']),
                   item['venue']['location']['distance']) for item in results]        
    except:
        venues = []
    return venues

# %%
#pthson@gmail.com
foursquare_client_id = 'L41NSWBFCRZHXFAIEDP2Y0ZIK22PSCH3HHI0UYNVWNK31MR3' # your Foursquare ID
foursquare_client_secret = 'I2WEPXFJG113SFJYPGTFGMKIYTBUJBMO2L4QTKSM50GTZ4X2' # your Foursquare Secret

# %%
import pickle

# %%
def get_restaurants(lats, lons):
    restaurants = {}
    coffee_shops = {}
    location_restaurants = []

    print('Obtaining venues around candidate locations:', end='')
    for lat, lon in zip(lats, lons):
        # Using radius=350 to meke sure we have overlaps/full coverage so we don't miss any restaurant (we're using dictionaries to remove any duplicates resulting from area overlaps)
        venues = get_venues_near_location(
            lat, lon, food_category, foursquare_client_id, foursquare_client_secret, radius=700, limit=100)
        area_restaurants = []
        for venue in venues:
            venue_id = venue[0]
            venue_name = venue[1]
            venue_categories = venue[2]
            venue_latlon = venue[3]
            venue_address = venue[4]
            venue_distance = venue[5]
            is_res, is_coffee = is_restaurant(
                venue_categories, specific_filter=coffee_shop_categories)
            if is_res:
                x, y = lonlat_to_xy(venue_latlon[1], venue_latlon[0])
                restaurant = (
                    venue_id, venue_name, venue_latlon[0], venue_latlon[1], venue_address, venue_distance, is_coffee, x, y)
                if venue_distance <= 300:
                    area_restaurants.append(restaurant)
                restaurants[venue_id] = restaurant
                if is_coffee:
                    coffee_shops[venue_id] = restaurant
        location_restaurants.append(area_restaurants)
        print(' .', end='')
    print(' done.')
    return restaurants, coffee_shops, location_restaurants

# %%
# Try to load from local file system in case we did this before
restaurants = {}
coffee_shops = {}
location_restaurants = []
loaded = False

try:
    with open('restaurants.pkl', 'rb') as f:
        restaurants = pickle.load(f)
    with open('coffee_shops.pkl', 'rb') as f:
        coffee_shops = pickle.load(f)
    with open('location_restaurants.pkl', 'rb') as f:
        location_restaurants = pickle.load(f)
    print('Drinking shop data loaded.')
    loaded = True
except:
    pass

# If load failed use the Foursquare API to get the data
if not loaded:
    restaurants, coffee_shops, location_restaurants = get_restaurants(
        latitudes, longitudes)

    # Let's persists this in local file system
    with open('restaurants.pkl', 'wb') as f:
        pickle.dump(restaurants, f)
    with open('coffee_shops.pkl', 'wb') as f:
        pickle.dump(coffee_shops, f)
    with open('location_restaurants.pkl', 'wb') as f:
        pickle.dump(location_restaurants, f)
# Out:
# Drinking shop data loaded.

# %%
import numpy as np

print('Total number of Drinking shop:', len(restaurants))
print('Total number of Coffee shop:', len(coffee_shops))
print('Percentage of Coffee shop: {:.2f}%'.format(len(coffee_shops) / len(restaurants) * 100))
print('Average number of Drinking shops in neighborhood:', np.array([len(r) for r in location_restaurants]).mean())
# Out:
# Total number of Drinking shop: 488
# Total number of Coffee shop: 164
# Percentage of Coffee shop: 33.61%
# Average number of Drinking shops in neighborhood: 2.34297520661157

# %%
print('List of all Drinking shops')
print('-----------------------')
for r in list(restaurants.values())[:10]:
    print(r)
print('...')
print('Total:', len(restaurants))
# Out:
# List of all Drinking shops
# -----------------------
# ('4ee7628d0aaf8939528f03c0', 'Hải sản Rạn Biển', 10.804503776759306, 106.66135831868787, 'Phan Thúc Duyện (Thăng Long), Hồ Chí Minh, Việt Nam', 695, False, 15218357.587846743, 10889446.096280014)
# ('544b2fed498e45ba2fce60c1', '한솔 - HanSol Korean Restaurant', 10.80768675612086, 106.66169972835752, 'Thang Long (Tan Binh), Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh, Việt Nam', 698, False, 15216624.595223978, 10889398.698742615)
# ('5299d49c11d2ce1a3b834225', 'GoGi House Superbowl', 10.808581665693495, 106.6644974467835, 'A43 Truong Son St., Tan Binh Dist., Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh, Việt Nam', 686, False, 15215945.48641174, 10890818.989033066)
# ('4c0f91afd64c0f4792ec295d', 'Thai House', 10.807818659834261, 106.66353061454383, '21B Hau Giang St., Tan Binh Dist., Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh, Việt Nam', 682, False, 15216423.741718374, 10890360.815515963)
# ('5486ed4b498e985cf50d8d6a', 'Phở Hùng', 10.808018555167669, 106.664831711076, '18 Trường Sơn, Việt Nam', 667, False, 15216223.94759542, 10891036.861589998)
# ('594f4106db1d81557e741b88', 'The Coffee House Thăng Long', 10.802981, 106.66062, '51 Thăng Long (Quận Tân Bình), Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh, Việt Nam', 692, True, 15219227.65552291, 10889163.524710394)
# ('4cc7add77be65481e3a62923', 'Chef Mamma', 10.808161970247793, 106.66442257565967, 'Saigonbowl Truong Son, Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh, Việt Nam', 677, False, 15216176.067601774, 10890809.444834234)
# ('5030ddeae4b0504d9f0e9e1d', 'Com Tam Ngon', 10.800945215150504, 106.65671555275753, '31 Cong Hoa St., Tan Binh Dist, Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh, Việt Nam', 685, False, 15220597.888208337, 10887236.49997327)
# ('4f9c9762e4b08ea0399ed41f', 'Bánh Cuốn Xuân Hường', 10.806306823296401, 106.66454960049694, 'Số 1, Sông Đà, P2, Q Tân Bình, Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh, Việt Nam', 694, False, 15217162.808173772, 10891010.297839686)
# ('54feac8c498e3399001671f1', 'iSushi Superbowl', 10.807782468660303, 106.66402591654078, 'A43 Truong Son St., Tan Binh Dist., Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh, Việt Nam', 699, False, 15216407.960954724, 10890626.251816012)
# ...
# Total: 488

# %%
print('List of Coffee shops')
print('---------------------------')
for r in list(coffee_shops.values())[:10]:
    print(r)
print('...')
print('Total:', len(coffee_shops))
# Out:
# List of Coffee shops
# ---------------------------
# ('594f4106db1d81557e741b88', 'The Coffee House Thăng Long', 10.802981, 106.66062, '51 Thăng Long (Quận Tân Bình), Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh, Việt Nam', 692, True, 15219227.65552291, 10889163.524710394)
# ('5110a2d7e4b0c512bbbb590e', 'Highlands Coffee', 10.800969054162756, 106.65785871609506, '15-18 Cong Hoa St., Tan Binh Dist., Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh, Việt Nam', 675, True, 15220504.054521177, 10887841.820892932)
# ('4e85650f775b9667badb867b', 'Monaco', 10.804765, 106.665007, 'Thành phố Hồ Chí Minh, Việt Nam', 675, True, 15217957.961512249, 10891364.010292241)
# ('501f598ce4b0373b151db3c7', 'Café BALI', 10.808274416526773, 106.66521745470263, '1B Tiền Giang, Phường 2, Quận Tân Bình, Việt Nam', 678, True, 15216059.184258165, 10891223.139634041)
# ('4df2d11352b100c2d7f8b533', 'Tuấn Ngọc Cafe', 10.798723332483378, 106.65841437512873, '308/13 Hoang Van Thu, Ward 4, Tan Binh (Ut Tich), Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh, Việt Nam', 689, True, 15221670.886028115, 10888298.01339618)
# ('573eab93498ed93baa3687b0', 'Highland Coffee @Pico Plaza', 10.8014, 106.653, 'Cộng Hoà, HCM, Việt Nam', 669, True, 15220616.60175887, 10885230.890678013)
# ('4d91d7589acaa143cc55f0f0', 'Cafe Cõi Riêng', 10.798968161687423, 106.6642307729039, '334A, Nguyễn Trọng Tuyển, Hochiminh, Thành phố Hồ Chí Minh, Việt Nam', 694, True, 15221125.9965314, 10891369.24752472)
# ('4daab1088154abafc2b28ecd', 'LUMOS Café', 10.798635109615109, 106.66394981322458, '383 Nguyễn Trọng Tuyển St., Phu Nhuan Dist., Thành phố Hồ Chí Minh, Thành phố Hồ Chí Minh, Việt Nam', 682, True, 15221324.882955251, 10891244.03027739)
# ('59008fcada5ede037e0d816d', 'GongCha Nguyen Thai Binh', 10.802663, 106.65702, '59 (Nguyễn Thái Bình), Tan Binh, Thành phố Hồ Chí Minh, Việt Nam', 662, True, 15219653.757209811, 10887275.04445863)
# ('51b99514498e541eebf74af8', 'Little Story Coffee', 10.800527485839764, 106.65251130328883, '01 Lê Trung Nghĩa, P12, Tân Bình, Việt Nam', 683, True, 15221119.812016584, 10885033.753727023)
# ...
# Total: 164

# %%
pd.DataFrame(coffee_shops).T
# Out:
#                                                  0  \
# 594f4106db1d81557e741b88  594f4106db1d81557e741b88
# 5110a2d7e4b0c512bbbb590e  5110a2d7e4b0c512bbbb590e
# 4e85650f775b9667badb867b  4e85650f775b9667badb867b
# 501f598ce4b0373b151db3c7  501f598ce4b0373b151db3c7
# 4df2d11352b100c2d7f8b533  4df2d11352b100c2d7f8b533
# ...                                            ...
# 54d21787498e6d4c8d5033b1  54d21787498e6d4c8d5033b1
# 4f249cd1e4b0717a68acad1c  4f249cd1e4b0717a68acad1c
# 54046d4c498ec4c3134339b1  54046d4c498ec4c3134339b1
# 4cb549d21b0af04d4b64c825  4cb549d21b0af04d4b64c825
# 4d8168e859d16dcb98e6f81b  4d8168e859d16dcb98e6f81b
#
#                                                     1        2        3  \
# 594f4106db1d81557e741b88  The Coffee House Thăng Long   10.803  106.661
# 5110a2d7e4b0c512bbbb590e             Highlands Coffee   10.801  106.658
# 4e85650f775b9667badb867b                       Monaco  10.8048  106.665
# 501f598ce4b0373b151db3c7                    Café BALI  10.8083  106.665
# 4df2d11352b100c2d7f8b533               Tuấn Ngọc Cafe  10.7987  106.658
# ...                                               ...      ...      ...
# 54d21787498e6d4c8d5033b1               My Life Coffee   10.778  106.689
# 4f249cd1e4b0717a68acad1c                  Cafe Về Cội  10.8055  106.689
# 54046d4c498ec4c3134339b1                   C. On Café  10.7808   106.69
# 4cb549d21b0af04d4b64c825                  Latino Cafe  10.7815  106.691
# 4d8168e859d16dcb98e6f81b   Nguyen Cafe Tran Quoc Thao  10.7792  106.691
#
#                                                                           4  \
# 594f4106db1d81557e741b88  51 Thăng Long (Quận Tân Bình), Thành phố Hồ Ch...
# 5110a2d7e4b0c512bbbb590e  15-18 Cong Hoa St., Tan Binh Dist., Thành phố ...
# 4e85650f775b9667badb867b                    Thành phố Hồ Chí Minh, Việt Nam
# 501f598ce4b0373b151db3c7   1B Tiền Giang, Phường 2, Quận Tân Bình, Việt Nam
# 4df2d11352b100c2d7f8b533  308/13 Hoang Van Thu, Ward 4, Tan Binh (Ut Tic...
# ...                                                                     ...
# 54d21787498e6d4c8d5033b1                              Truong Dinh, Việt Nam
# 4f249cd1e4b0717a68acad1c                     Lam Sơn, Hồ Chí Minh, Việt Nam
# 54046d4c498ec4c3134339b1  23B Ngô Thời Nhiệm, Q.3, Thành phố Hồ Chí Minh...
# 4cb549d21b0af04d4b64c825        Lê Quý Đôn, Thành phố Hồ Chí Minh, Việt Nam
# 4d8168e859d16dcb98e6f81b  Trần Quốc Thảo (Nguyễn Đình Chiểu), Thành phố ...
#
#                             5     6            7            8
# 594f4106db1d81557e741b88  692  True  1.52192e+07  1.08892e+07
# 5110a2d7e4b0c512bbbb590e  675  True  1.52205e+07  1.08878e+07
# 4e85650f775b9667badb867b  675  True   1.5218e+07  1.08914e+07
# 501f598ce4b0373b151db3c7  678  True  1.52161e+07  1.08912e+07
# 4df2d11352b100c2d7f8b533  689  True  1.52217e+07  1.08883e+07
# ...                       ...   ...          ...          ...
# 54d21787498e6d4c8d5033b1  601  True  1.52306e+07  1.09063e+07
# 4f249cd1e4b0717a68acad1c  120  True  1.52159e+07  1.09038e+07
# 54046d4c498ec4c3134339b1  663  True   1.5229e+07  1.09065e+07
# 4cb549d21b0af04d4b64c825  688  True  1.52286e+07  1.09068e+07
# 4d8168e859d16dcb98e6f81b  689  True  1.52298e+07  1.09068e+07
#
# [164 rows x 9 columns]

# %%
print('Drinking shops around location')
print('---------------------------')
for i in range(100, 110):
    rs = location_restaurants[i][:8]
    names = ', '.join([r[1] for r in rs])
    print('Drinking shops around location {}: {}'.format(i+1, names))
# Out:
# Drinking shops around location
# ---------------------------
# Drinking shops around location 101: GoGi House Superbowl, Phở Hùng, Thai House, Chef Mamma, Bánh Cuốn Xuân Hường, iSushi Superbowl, Tokyo Deli Truong Son, Món Huế Restaurant
# Drinking shops around location 102: Phở Hùng, Ốc Út Liên, Thai House, Chef Mamma, Bánh Cuốn Xuân Hường, iSushi Superbowl, Tokyo Deli Truong Son, Thien Huong Sushi
# Drinking shops around location 103: Ốc Út Liên, Bánh Cuốn Xuân Hường, Tokyo Deli Truong Son, Monaco, Pho 24, Hai san Ut Lien, Biển Đông Restaurant
# Drinking shops around location 104: Ốc Út Liên, Monaco, Biển Đông Restaurant, Pho 24, Hai san Ut Lien
# Drinking shops around location 105: Bun Cha Xuan Tu, Bún Chả Xuân Tú, Biển Đông Restaurant, Monaco
# Drinking shops around location 106: Bun Cha Xuan Tu, Cafe Cõi Riêng, Bún Chả Xuân Tú, Vườn Phố Restaurant, Secret Garden Tea and Pastries
# Drinking shops around location 107: Bun Cha Xuan Tu, Cafe Cõi Riêng, LUMOS Café, Bún Chả Xuân Tú, Ốc Châu, Nhà hàng Quê Nhà 2
# Drinking shops around location 108: Bun Cha Xuan Tu, Cafe Cõi Riêng, LUMOS Café, Bún Chả Xuân Tú, Ốc Châu, Nhà hàng Quê Nhà 2, Hoang Lan Restaurant
# Drinking shops around location 109: Bun Cha Xuan Tu, Cafe Cõi Riêng, LUMOS Café, Ốc Châu, Quá Ngon, Hoang Lan Restaurant, Nhà hàng Quê Nhà 2, SumoBBQ Lê Văn Sỹ
# Drinking shops around location 110: Cafe Cõi Riêng, LUMOS Café, Ốc Châu, Quá Ngon, Hoang Lan Restaurant, SumoBBQ Lê Văn Sỹ, Nhà hàng Quê Nhà 2

# %%
map_hcmc = folium.Map(location=hcmc_center, zoom_start=13)
folium.Marker(hcmc_center, popup='Central location').add_to(map_hcmc)
for res in restaurants.values():
    lat = res[2]; lon = res[3]
    is_coffee = res[6]
    color = 'red' if is_coffee else 'blue'
    folium.CircleMarker([lat, lon], radius=3, color=color, fill=True, fill_color=color, fill_opacity=1).add_to(map_hcmc)
map_hcmc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Looking good. So now we have all the coffee shop in area within few kilometers from the central location.

# %% [markdown]
# # Methodology <a name="methodology"></a>

# %% [markdown]
# In this project, we will find and detect areas of the city that have low density of the coffee shop, particularly those with low number of coffee shop. We will limit our analysis to an area about 12 km around the central location. That is the position between Tan Son Nhat International Airport and the central city (coordinates taken at the People's Committee of District 1). The method of implementation consists of three stages as follows:
#
# - Stage #1: Collecting the required data: location and type of every restaurant within 7 km from the central location that we have defined above. According to Foursquare about categorizations of the coffee shops. We search the location of the coordinates of the cafes in the same mutual area.
#
# - Stage #2: After obtaining the data collected from stage #1, we proceed to the analysis phase. The initial analysis process will data exploration, such as the density of the coffee shop across different areas. Using heatmaps to identify a few promising areas close to center with the low number of coffee shops in general and focus our attention on those areas.
#
# - Stage #3: Focus on most promising areas and within those create clusters of locations that meet some basic requirements established in discussion with stakeholders: (1) Take into consideration locations with no more than two the coffee shop in a radius of 400 meters, and we want locations without the coffee shops in radius of 600 meters. (2) Resenting a map of all such locations. (3) Creating clusters of those locations to identify a general area which should be a starting point for final 'street level' exploration and search for optimal venue location by stakeholders.

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# Let's perform some basic explanatory data analysis and derive some additional info from our raw data. First let's count the **number of restaurants in every area candidate**:

# %%
location_restaurants_count = [len(res) for res in location_restaurants]

df_locations['Drinking shops in area'] = location_restaurants_count

print('Average number of restaurants in every area with radius = 350m:', np.array(location_restaurants_count).mean())

df_locations.head(10)
# Out:
# Average number of restaurants in every area with radius = 350m: 2.34297520661157
#                                              Address   Latitude   Longitude  \
# 0  30 Phan Thúc Duyện, Phường 4, Tân Bình, Hồ Chí...  10.806386  106.659513
# 1  6/22 Hẻm số 6 Đồ Sơn, Phường 4, Tân Bình, Hồ C...  10.805288  106.659364
# 2        27 Sầm Sơn, Phường 4, Tân Bình, Hồ Chí Minh  10.804190  106.659216
# 3  36/14 Hẻm 36 Giải Phóng, Phường 4, Tân Bình, H...  10.803092  106.659068
# 4  2/15 Hẻm số 2 Đồng Khởi, Phường 4, Tân Bình, H...  10.801995  106.658919
# 5       15 Cộng Hòa, Phường 4, Tân Bình, Hồ Chí Minh  10.800897  106.658771
# 6  51 Nguyễn Thái Bình, Phường 4, Tân Bình, Hồ Ch...  10.799800  106.658623
# 7  308/5 Hoàng Văn Thụ, Phường 4, Tân Bình, Hồ Ch...  10.798702  106.658475
# 8  40a, 40B Út Tịch, Phường 4, Tân Bình, Hồ Chí Minh  10.797605  106.658326
# 9  437/13- 437/15 Hoàng Văn Thụ, Phường 4, Tân Bì...  10.796508  106.658178
#
#               X             Y  Distance from center  Drinking shops in area
# 0  1.521749e+07  1.088831e+07          11945.259904                       3
# 1  1.521809e+07  1.088831e+07          11793.609888                       2
# 2  1.521869e+07  1.088831e+07          11670.871184                       2
# 3  1.521929e+07  1.088831e+07          11577.963300                       3
# 4  1.521989e+07  1.088831e+07          11515.608286                       3
# 5  1.522049e+07  1.088831e+07          11484.303818                       4
# 6  1.522109e+07  1.088831e+07          11484.303818                       3
# 7  1.522169e+07  1.088831e+07          11515.608286                       2
# 8  1.522229e+07  1.088831e+07          11577.963300                       1
# 9  1.522289e+07  1.088831e+07          11670.871184                       3

# %%
df_locations.shape
# Out:
# (1452, 7)

# %% [markdown]
# OK, now let's calculate the **distance to nearest Coffee shop from every area candidate center** (not only those within 300m - we want distance to closest one, regardless of how distant it is).

# %%
distances_to_coffee_shop = []

for area_x, area_y in zip(xs, ys):
    min_distance = 10000
    for res in coffee_shops.values():
        res_x = res[7]
        res_y = res[8]
        d = calc_xy_distance(area_x, area_y, res_x, res_y)
        if d<min_distance:
            min_distance = d
    distances_to_coffee_shop.append(min_distance)

df_locations['Distance to Coffee shop'] = distances_to_coffee_shop

# %%
df_locations.head(10)
# Out:
#                                              Address   Latitude   Longitude  \
# 0  30 Phan Thúc Duyện, Phường 4, Tân Bình, Hồ Chí...  10.806386  106.659513
# 1  6/22 Hẻm số 6 Đồ Sơn, Phường 4, Tân Bình, Hồ C...  10.805288  106.659364
# 2        27 Sầm Sơn, Phường 4, Tân Bình, Hồ Chí Minh  10.804190  106.659216
# 3  36/14 Hẻm 36 Giải Phóng, Phường 4, Tân Bình, H...  10.803092  106.659068
# 4  2/15 Hẻm số 2 Đồng Khởi, Phường 4, Tân Bình, H...  10.801995  106.658919
# 5       15 Cộng Hòa, Phường 4, Tân Bình, Hồ Chí Minh  10.800897  106.658771
# 6  51 Nguyễn Thái Bình, Phường 4, Tân Bình, Hồ Ch...  10.799800  106.658623
# 7  308/5 Hoàng Văn Thụ, Phường 4, Tân Bình, Hồ Ch...  10.798702  106.658475
# 8  40a, 40B Út Tịch, Phường 4, Tân Bình, Hồ Chí Minh  10.797605  106.658326
# 9  437/13- 437/15 Hoàng Văn Thụ, Phường 4, Tân Bì...  10.796508  106.658178
#
#               X             Y  Distance from center  Drinking shops in area  \
# 0  1.521749e+07  1.088831e+07          11945.259904                       3
# 1  1.521809e+07  1.088831e+07          11793.609888                       2
# 2  1.521869e+07  1.088831e+07          11670.871184                       2
# 3  1.521929e+07  1.088831e+07          11577.963300                       3
# 4  1.521989e+07  1.088831e+07          11515.608286                       3
# 5  1.522049e+07  1.088831e+07          11484.303818                       4
# 6  1.522109e+07  1.088831e+07          11484.303818                       3
# 7  1.522169e+07  1.088831e+07          11515.608286                       2
# 8  1.522229e+07  1.088831e+07          11577.963300                       1
# 9  1.522289e+07  1.088831e+07          11670.871184                       3
#
#    Distance to Coffee shop
# 0              1936.913461
# 1              1422.432468
# 2              1007.469353
# 3               852.452268
# 4               776.172745
# 5               471.641500
# 6               583.693624
# 7                22.405614
# 8               231.524389
# 9               433.386300

# %%
print('Average distance to closest Coffee shop from each area center:',
      df_locations['Distance to Coffee shop'].mean())
# Out:
# Average distance to closest Coffee shop from each area center: 1325.8583358295975

# %% [markdown]
# OK, so **on average Coffee shop can be found within ~500m** from every area center candidate. That's fairly close, so we need to filter our areas carefully!

# %% [markdown]
# Let's crete a map showing **heatmap / density of drinking shops** and try to extract some meaningfull info from that. Also, let's show **borders of central location** on our map and a few circles indicating distance of 1km, 2km and 3km from central location.

# %%
restaurant_latlons = [[res[2], res[3]] for res in restaurants.values()]

coffee_latlons = [[res[2], res[3]] for res in coffee_shops.values()]

# %%
from folium import plugins
from folium.plugins import HeatMap

map_hcmc = folium.Map(location=hcmc_center, zoom_start=13)
folium.TileLayer('cartodbpositron').add_to(map_hcmc) #cartodbpositron cartodbdark_matter
HeatMap(restaurant_latlons).add_to(map_hcmc)
folium.Marker(hcmc_center).add_to(map_hcmc)
folium.Circle(hcmc_center, radius=1000, fill=False, color='white').add_to(map_hcmc)
folium.Circle(hcmc_center, radius=2000, fill=False, color='white').add_to(map_hcmc)
folium.Circle(hcmc_center, radius=3000, fill=False, color='white').add_to(map_hcmc)
map_hcmc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Looks like a few pockets of low restaurant density closest to city center can be found **south, south-east and east from Alexanderplatz**.
#
# Let's create another heatmap map showing **heatmap/density of Coffee shops** only.

# %%
map_hcmc = folium.Map(location=hcmc_center, zoom_start=13)
folium.TileLayer('cartodbpositron').add_to(map_hcmc) #cartodbpositron cartodbdark_matter
HeatMap(coffee_latlons).add_to(map_hcmc)
folium.Marker(hcmc_center).add_to(map_hcmc)
folium.Circle(hcmc_center, radius=1000, fill=False, color='white').add_to(map_hcmc)
folium.Circle(hcmc_center, radius=2000, fill=False, color='white').add_to(map_hcmc)
folium.Circle(hcmc_center, radius=3000, fill=False, color='white').add_to(map_hcmc)
map_hcmc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
roi_x_min = hcmc_center_x - 2000
roi_y_max = hcmc_center_y + 1000
roi_width = 5000
roi_height = 5000
roi_center_x = roi_x_min + 2500
roi_center_y = roi_y_max - 2500
roi_center_lon, roi_center_lat = xy_to_lonlat(roi_center_x, roi_center_y)
roi_center = [roi_center_lat, roi_center_lon]

map_hcmcn = folium.Map(location=roi_center, zoom_start=14)
HeatMap(restaurant_latlons).add_to(map_hcmc)
folium.Marker(hcmc_center).add_to(map_hcmc)
folium.Circle(roi_center, radius=2500, color='white', fill=True, fill_opacity=0.4).add_to(map_hcmc)
map_hcmc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
k = math.sqrt(3) / 2 # Vertical offset for hexagonal grid cells
x_step = 100
y_step = 100 * k 
roi_y_min = roi_center_y - 2500

roi_latitudes = []
roi_longitudes = []
roi_xs = []
roi_ys = []
for i in range(0, int(51/k)):
    y = roi_y_min + i * y_step
    x_offset = 50 if i%2==0 else 0
    for j in range(0, 51):
        x = roi_x_min + j * x_step + x_offset
        d = calc_xy_distance(roi_center_x, roi_center_y, x, y)
        if (d <= 2501):
            lon, lat = xy_to_lonlat(x, y)
            roi_latitudes.append(lat)
            roi_longitudes.append(lon)
            roi_xs.append(x)
            roi_ys.append(y)

print(len(roi_latitudes), 'candidate neighborhood centers generated.')
# Out:
# 2261 candidate neighborhood centers generated.

# %%
def count_restaurants_nearby(x, y, restaurants, radius=250):    
    count = 0
    for res in restaurants.values():
        res_x = res[7]; res_y = res[8]
        d = calc_xy_distance(x, y, res_x, res_y)
        if d<=radius:
            count += 1
    return count

def find_nearest_restaurant(x, y, restaurants):
    d_min = 100000
    for res in restaurants.values():
        res_x = res[7]; res_y = res[8]
        d = calc_xy_distance(x, y, res_x, res_y)
        if d<=d_min:
            d_min = d
    return d_min

roi_restaurant_counts = []
roi_coffee_distances = []

print('Generating data on location candidates... ', end='')
for x, y in zip(roi_xs, roi_ys):
    count = count_restaurants_nearby(x, y, restaurants, radius=250)
    roi_restaurant_counts.append(count)
    distance = find_nearest_restaurant(x, y, coffee_shops)
    roi_coffee_distances.append(distance)
print('done.')
# Out:
# Generating data on location candidates... done.

# %%
# Let's put this into dataframe
df_roi_locations = pd.DataFrame({'Latitude':roi_latitudes,
                                 'Longitude':roi_longitudes,
                                 'X':roi_xs,
                                 'Y':roi_ys,
                                 'Drinking shops nearby':roi_restaurant_counts,
                                 'Distance to Coffee shop':roi_coffee_distances})

df_roi_locations.head(10)
# Out:
#     Latitude   Longitude             X             Y  Drinking shops nearby  \
# 0  10.797690  106.672423  1.522124e+07  1.089579e+07                      0
# 1  10.797507  106.672398  1.522134e+07  1.089579e+07                      0
# 2  10.798675  106.672721  1.522069e+07  1.089588e+07                      0
# 3  10.798492  106.672696  1.522079e+07  1.089588e+07                      0
# 4  10.798309  106.672671  1.522089e+07  1.089588e+07                      0
# 5  10.798126  106.672646  1.522099e+07  1.089588e+07                      0
# 6  10.797943  106.672621  1.522109e+07  1.089588e+07                      0
# 7  10.797760  106.672596  1.522119e+07  1.089588e+07                      0
# 8  10.797578  106.672571  1.522129e+07  1.089588e+07                      0
# 9  10.797395  106.672546  1.522139e+07  1.089588e+07                      0
#
#    Distance to Coffee shop
# 0               843.916846
# 1               846.126415
# 2               514.806240
# 3               614.504238
# 4               714.286674
# 5               814.122501
# 6               913.994223
# 7               933.487247
# 8               930.125103
# 9               937.479053

# %% [markdown]
# OK. Let us now **filter** those locations: we're interested only in **locations with no more than two restaurants in radius of 250 meters**, and **no Coffee shops in radius of 400 meters**.

# %%
good_res_count = np.array((df_roi_locations['Drinking shops nearby']<=2))
print('Locations with no more than two drinking shops nearby:', good_res_count.sum())

good_ita_distance = np.array(df_roi_locations['Distance to Coffee shop']>=400)
print('Locations with no Coffee shops within 400m:', good_ita_distance.sum())

good_locations = np.logical_and(good_res_count, good_ita_distance)
print('Locations with both conditions met:', good_locations.sum())

df_good_locations = df_roi_locations[good_locations]
# Out:
# Locations with no more than two drinking shops nearby: 2238
# Locations with no Coffee shops within 400m: 1852
# Locations with both conditions met: 1834

# %% [markdown]
# Looking good. What we have now is a clear indication of zones with low number of restaurants in vicinity, and *no* Coffee shops at all nearby.
#
# Let us now **cluster** those locations to create **centers of zones containing good locations**. Those zones, their centers and addresses will be the final result of our analysis.

# %%
from sklearn.cluster import KMeans

good_latitudes = df_good_locations['Latitude'].values
good_longitudes = df_good_locations['Longitude'].values
number_of_clusters = 15

good_xys = df_good_locations[['X', 'Y']].values
kmeans = KMeans(n_clusters=number_of_clusters, random_state=0).fit(good_xys)

cluster_centers = [xy_to_lonlat(cc[0], cc[1]) for cc in kmeans.cluster_centers_]

map_hcmc = folium.Map(location=roi_center, zoom_start=14)
folium.TileLayer('cartodbpositron').add_to(map_hcmc)
HeatMap(restaurant_latlons).add_to(map_hcmc)
folium.Circle(roi_center, radius=2500, color='white', fill=True, fill_opacity=0.4).add_to(map_hcmc)
folium.Marker(hcmc_center).add_to(map_hcmc)
for lon, lat in cluster_centers:
    folium.Circle([lat, lon], radius=700, color='green', fill=True, fill_opacity=0.25).add_to(map_hcmc) 
for lat, lon in zip(good_latitudes, good_longitudes):
    folium.CircleMarker([lat, lon], radius=2, color='blue', fill=True, fill_color='blue', fill_opacity=1).add_to(map_hcmc)
#map_hcmc

# %% [markdown]
# Not bad - our clusters represent groupings of most of the candidate locations and cluster centers are placed nicely in the middle of the zones 'rich' with location candidates.
#
# Addresses of those cluster centers will be a good starting point for exploring the neighborhoods to find the best possible location based on neighborhood specifics.
#
# Let's see those zones on a city map without heatmap, using shaded areas to indicate our clusters:

# %% [markdown]
# Finaly, let's **reverse geocode those candidate area centers to get the addresses** which can be presented to stakeholders.

# %%
candidate_area_addresses = []
print('==============================================================')
print('Addresses of centers of areas recommended for further analysis')
print('==============================================================\n')
for lon, lat in cluster_centers:
    addr = get_address(google_api_key, lat, lon).replace(', Vietnam', '')
    candidate_area_addresses.append(addr)    
    x, y = lonlat_to_xy(lon, lat)
    d = calc_xy_distance(x, y, hcmc_center_x, hcmc_center_y)
    print('{}{} => {:.1f}km from my Center'.format(addr, ' '*(50-len(addr)), d/1000))
# Out:
# ==============================================================
# Addresses of centers of areas recommended for further analysis
# ==============================================================
#
# 223A Trần Huy Liệu, Phường 8, Phú Nhuận, Hồ Chí Minh => 1.5km from my Center
# 129 Nguyễn Đình Chính, Phường 8, Phú Nhuận, Hồ Chí Minh => 1.9km from my Center
# 232 Nguyễn Trọng Tuyển, Phường 8, Phú Nhuận, Hồ Chí Minh => 3.5km from my Center
# 10 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh => 1.1km from my Center
# 11/12 Nguyễn Trọng Tuyển, Phường 15, Phú Nhuận, Hồ Chí Minh => 0.6km from my Center
# 251/4 Nguyễn Văn Trỗi, Phường 10, Phú Nhuận, Hồ Chí Minh => 3.6km from my Center
# 12/18 Chiến Thắng, Phường 9, Phú Nhuận, Hồ Chí Minh => 2.6km from my Center
# 94/8 Trần Khắc Chân, Phường 9, Phú Nhuận, Hồ Chí Minh => 1.9km from my Center
# 90A Nguyễn Trọng Tuyển, Phường 15, Phú Nhuận, Hồ Chí Minh => 0.5km from my Center
# 10/8i Trần Hữu Trang, Phường 11, Phú Nhuận, Hồ Chí Minh => 3.0km from my Center
# 73/2/3 Duy Tân, Phường 15, Phú Nhuận, Hồ Chí Minh  => 1.3km from my Center
# 159/39E Hoàng Văn Thụ, Phường 8, Phú Nhuận, Hồ Chí Minh => 2.5km from my Center
# 76 Nguyễn Văn Trỗi, Phường 8, Phú Nhuận, Hồ Chí Minh => 2.7km from my Center
# 117 - 119 Nguyễn Văn Trỗi, Phường 12, Phú Nhuận, Hồ Chí Minh => 2.2km from my Center
# 194 Hoàng Văn Thụ, Phường 9, Phú Nhuận, Hồ Chí Minh => 3.2km from my Center

# %%
map_hcmc = folium.Map(location=roi_center, zoom_start=14)
folium.Circle(hcmc_center, radius=50, color='red', fill=True, fill_color='red', fill_opacity=1).add_to(map_hcmc)
for lonlat, addr in zip(cluster_centers, candidate_area_addresses):
    folium.Marker([lonlat[1], lonlat[0]], popup=addr).add_to(map_hcmc) 
for lat, lon in zip(good_latitudes, good_longitudes):
    pass
map_hcmc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
